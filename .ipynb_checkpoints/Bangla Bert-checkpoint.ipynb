# %%
import pandas as pd
from pandas import read_excel
import numpy as np
import re
from re import sub
import multiprocessing
from unidecode import unidecode
import os
from time import time 
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import LSTM,Dense,Dropout,Activation,Embedding,Flatten,Bidirectional,MaxPooling2D, Conv1D, MaxPooling1D
from keras.optimizers import SGD,Adam
from keras import regularizers
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import h5py
import csv
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

# %%
file_path = 'corpus_all.txt'  # Replace with the actual path to your text file

lines = []  # Empty list to store the lines

try:
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            lines.append(line.strip())  # Append the line to the list, removing any leading/trailing whitespace

except FileNotFoundError:
    print("File not found. Please check the file path and try again.")

print(lines[0])
# Out:
# sad	বরাবর, মাননীয় প্রধানমন্ত্রী গণপ্রজাতন্ত্রী বাংলাদেশ সরকার। মাননীয় প্রধানমন্ত্রী, আমি আপনার স্বপ্নের ডিজিটাল বাংলাদেশের স্বপ্ন বুকে লালনকারী একজন সাধারণ ছাত্র। শত সহস্র আশা এবং দেশের প্রতি এক অকৃত্তিম ভালোবাসা এবং নিজেকে দেশের জন্য যোগ্য করে গড়ে তোলার এক তীব্র আকাঙ্ক্ষা নিয়ে ভর্তি হয়েছিলাম আপনার নিজ হাতে প্রতিষ্ঠিত দেশের অন্যতম বিশ্ববিদ্যালয় যশোর বিজ্ঞান ও প্রযুক্তি বিশ্ববিদ্যালয়ে। একটি ডিজিটাল বাংলাদেশ গড়তে এ ধরণের একটি প্রযুক্তি বিশ্ববিদ্যালয় প্রতিষ্ঠা করা নিঃসন্দেহে আপনার দেশ পরিচালনার একটি বিচক্ষণতার পরিচয় বহন করে। আপনি যশোর বাসির স্বপ্নের এই প্রতিষ্ঠানে শত শত কোটি টাকা বিনিয়োগ করেছেন দুহাত উজাড় করে। কিন্তু অত্যন্ত দুঃখের সাথে সেই বিশ্ববিদ্যালয় জীবনের সূচনালগ্ন থেকে অনুভব করছি যে, অনেক পাওয়ার আনন্দে যখন শিক্ষার্থীদের মনপ্রান উজাড় করে পড়ালেখা করার কথা, তার বিপরীতে এই কমলমতি শিক্ষার্থীরা সদা দিনাতিপাত করছে প্রাণ নাশের হুমকি, শ্লীলতাহানীর গ্লানি, আর ছাত্রত্ত বাতিল হওয়ার হুমকি নিয়ে। সম্মানিত শিক্ষকদের কে মারতে যাওয়া, গলা কেটে ফেলার হুমকি, প্রাণ নাশের হুমকি, কটূক্তি করা আজ এখানে নিয়মিত ঘটনা। মাননীয় প্রধানমন্ত্রী যেখানে শিক্ষার্থীরা শিক্ষকদের পিতামাতার মত সম্মান করে তাদের সামনে একজন চতুর্থ শ্রেণীর কর্মচারীর দ্বারা শিক্ষকদের নিয়মিত এমন ঘটনার শিকার হওয়া আমাদের ডিজিটাল বাংলাদেশের স্বপ্নে যেন পাক হানাদার বাহিনীর মত হানা দিয়ে যায়। যখন চোখের সামনে আমার ছাত্রী বোনের স্লিলতাহানীর চেষ্টা করা হয়, আর প্রতিবাদ করতে গিয়ে বহিষ্কার হতে হয় শিক্ষার্থীদের তখন মনে হয় সেই ভাষা আন্দোলন আর মুক্তিযুদ্ধের বিভীষিকাময় দিন গুলোর কথা। আপনার সুশাসনের বাংলাদেশে এমন একটি আদর্শ বিশ্ববিদ্যালয়ে, বিশ্ববিদ্যালয়ের প্রশাসনের পোষা সন্ত্রাসী মাদক ব্যাবসায়ী, শিক্ষকদের লাঞ্চিত করা, ছাত্রদের জীবন নিয়ে ছিনিমিনি খেলা, এবং ছাত্রীদের লাঞ্চিত করার যে বিরল নজীর স্থাপন করেছে তা আপনার আমাদের স্বপ্নের সোনার বাংলা গড়ার সম্পূর্ণ পরিপন্থী। মাননীয় প্রধানমন্ত্রী হাজার হাজার শিক্ষক, শিক্ষার্থীর মিলিত আর্তনাদে আজ যশোরের আকাশ বাতাস প্রকম্পিত, বসরের পর বসর একজন কর্মচারী প্রশাসনের ছত্রছায়ায় এমন অন্যায় করে যাচ্ছে তার প্রতিকার কি আজও হবে না?? জীবনের সোনালি সময় গুলো চলে যাচ্ছে ক্লাস পরীক্ষা না দিয়ে, যশোর বিশ্ববিদ্যালয় বন্ধ দুই সপ্তাহ যাবত। আর কতটুকু সময় পেরোলে আমরা নতুন সূর্য দেখব? আর কত শিক্ষক লাঞ্চিত হলে, ছাত্রী লাঞ্চিত হলে, ছাত্রদের জীবন বিপন্ন হলে আপনার সাহায্য পাব?? অনুগ্রহ করে আমাদের স্বপ্ন গুলো বাচাতে এগিয়ে আসুন। আপনার সুদৃষ্টির পথ পানে চেয়ে দিন গুনছি আমরা। বিনীত মোঃ নাসির উদ্দিন বাদল জীন প্রকৌশল ও জীব প্রযুক্তি বিভাগ যশোর বিজ্ঞান ও প্রযুক্তি বিশ্ববিদ্যালয়।

# %%
#file_path = 'corpus_all.txt'  # Replace with the actual path to your text file
first_words = []  # Empty list to store the first words

try:
    for line in lines:
        words = line.strip().split()  # Split the line into words
        if words:
            first_word = words[0]  # Get the first word
            first_words.append(first_word)  # Append the first word to the list

except FileNotFoundError:
    print("File not found. Please check the file path and try again.")

# Print the first words or perform any desired processing
distinct_values = set(first_words)
for value in distinct_values:
    print(value)
# Out:
# sad
# fear
# angry
# surprise
# happy
# disgust

# %%
# Define the status levels
status_levels = ["happy","angry","fear","disgust","sad","surprise", "fear"]

# Initialize a list to store the extracted status levels and sentences
extracted_data = []

# Iterate over the texts
for text in lines:
    # Initialize variables to store the extracted status level and sentence
    status = ""
    sentence = ""

    # Iterate over the status levels
    for level in status_levels:
        if level in text:
            # Split the text based on the status level
            split_text = text.split(level, 1)

            # Extract the status level and sentence
            status = level
            sentence = split_text[1].strip()
            break

    # Append the extracted status level and sentence to the list
    extracted_data.append({"Status": status, "Sentence": sentence})

# %%
# Print the extracted data
for data in extracted_data:
    print("Status:", data["Status"])
    print("Sentence:", data["Sentence"])
    print()
# Out:
# Status: sad
# Sentence: বরাবর, মাননীয় প্রধানমন্ত্রী গণপ্রজাতন্ত্রী বাংলাদেশ সরকার। মাননীয় প্রধানমন্ত্রী, আমি আপনার স্বপ্নের ডিজিটাল বাংলাদেশের স্বপ্ন বুকে লালনকারী একজন সাধারণ ছাত্র। শত সহস্র আশা এবং দেশের প্রতি এক অকৃত্তিম ভালোবাসা এবং নিজেকে দেশের জন্য যোগ্য করে গড়ে তোলার এক তীব্র আকাঙ্ক্ষা নিয়ে ভর্তি হয়েছিলাম আপনার নিজ হাতে প্রতিষ্ঠিত দেশের অন্যতম বিশ্ববিদ্যালয় যশোর বিজ্ঞান ও প্রযুক্তি বিশ্ববিদ্যালয়ে। একটি ডিজিটাল বাংলাদেশ গড়তে এ ধরণের একটি প্রযুক্তি বিশ্ববিদ্যালয় প্রতিষ্ঠা করা নিঃসন্দেহে আপনার দেশ পরিচালনার একটি বিচক্ষণতার পরিচয় বহন করে। আপনি যশোর বাসির স্বপ্নের এই প্রতিষ্ঠানে শত শত কোটি টাকা বিনিয়োগ করেছেন দুহাত উজাড় করে। কিন্তু অত্যন্ত দুঃখের সাথে সেই বিশ্ববিদ্যালয় জীবনের সূচনালগ্ন থেকে অনুভব করছি যে, অনেক পাওয়ার আনন্দে যখন শিক্ষার্থীদের মনপ্রান উজাড় করে পড়ালেখা করার কথা, তার বিপরীতে এই কমলমতি শিক্ষার্থীরা সদা দিনাতিপাত করছে প্রাণ নাশের হুমকি, শ্লীলতাহানীর গ্লানি, আর ছাত্রত্ত বাতিল হওয়ার হুমকি নিয়ে। সম্মানিত শিক্ষকদের কে মারতে যাওয়া, গলা কেটে ফেলার হুমকি, প্রাণ নাশের হুমকি, কটূক্তি করা আজ এখানে নিয়মিত ঘটনা। মাননীয় প্রধানমন্ত্রী যেখানে শিক্ষার্থীরা শিক্ষকদের পিতামাতার মত সম্মান করে তাদের সামনে একজন চতুর্থ শ্রেণীর কর্মচারীর দ্বারা শিক্ষকদের নিয়মিত এমন ঘটনার শিকার হওয়া আমাদের ডিজিটাল বাংলাদেশের স্বপ্নে যেন পাক হানাদার বাহিনীর মত হানা দিয়ে যায়। যখন চোখের সামনে আমার ছাত্রী বোনের স্লিলতাহানীর চেষ্টা করা হয়, আর প্রতিবাদ করতে গিয়ে বহিষ্কার হতে হয় শিক্ষার্থীদের তখন মনে হয় সেই ভাষা আন্দোলন আর মুক্তিযুদ্ধের বিভীষিকাময় দিন গুলোর কথা। আপনার সুশাসনের বাংলাদেশে এমন একটি আদর্শ বিশ্ববিদ্যালয়ে, বিশ্ববিদ্যালয়ের প্রশাসনের পোষা সন্ত্রাসী মাদক ব্যাবসায়ী, শিক্ষকদের লাঞ্চিত করা, ছাত্রদের জীবন নিয়ে ছিনিমিনি খেলা, এবং ছাত্রীদের লাঞ্চিত করার যে বিরল নজীর স্থাপন করেছে তা আপনার আমাদের স্বপ্নের সোনার বাংলা গড়ার সম্পূর্ণ পরিপন্থী। মাননীয় প্রধানমন্ত্রী হাজার হাজার শিক্ষক, শিক্ষার্থীর মিলিত আর্তনাদে আজ যশোরের আকাশ বাতাস প্রকম্পিত, বসরের পর বসর একজন কর্মচারী প্রশাসনের ছত্রছায়ায় এমন অন্যায় করে যাচ্ছে তার প্রতিকার কি আজও হবে না?? জীবনের সোনালি সময় গুলো চলে যাচ্ছে ক্লাস পরীক্ষা না দিয়ে, যশোর বিশ্ববিদ্যালয় বন্ধ দুই সপ্তাহ যাবত। আর কতটুকু সময় পেরোলে আমরা নতুন সূর্য দেখব? আর কত শিক্ষক লাঞ্চিত হলে, ছাত্রী লাঞ্চিত হলে, ছাত্রদের জীবন বিপন্ন হলে আপনার সাহায্য পাব?? অনুগ্রহ করে আমাদের স্বপ্ন গুলো বাচাতে এগিয়ে আসুন। আপনার সুদৃষ্টির পথ পানে চেয়ে দিন গুনছি আমরা। বিনীত মোঃ নাসির উদ্দিন বাদল জীন প্রকৌশল ও জীব প্রযুক্তি বিভাগ যশোর বিজ্ঞান ও প্রযুক্তি বিশ্ববিদ্যালয়।
#
# Status: sad
# Sentence: তদন্ত করে লাভ কী ? কোন দিন কোন তদন্তের পর কিছু হয়েছে বলে কী আপনার মন পরে ? রাজনৈতিক শক্তির সামনে তদন্ত কিছুই করতে পারবে না ! আর তাই আমাদের সামান্য মাথাব্যাথা, পেট ব্যাথা হলে বা কলে পরিস্কার পানি না পেলে, সঠিক বিচার না পেলে আমরা আমাদের মাননীয় প্রধামন্ত্রীর দৃস্টি আর্কষন করে থাকি ! কিন্তু সকল দায়িত্ব কী তার একা ? তিনিই বা কেন লাথি দিয়ে এদের বহিস্কার করতে পারে না ?
#
# Status: angry
# Sentence: দেশকি মধ্যম আয়ের দেশে রুপান্তর হচ্ছে নাকি মগের মুলুকের দেশে পরিনত হচ্ছে?
#
# Status: happy
# Sentence: আমি গর্বিত আমি মুসলিম। আমি সংগ্রামী। আমি যোদ্ধা। আমি চির রণবীর। আমি আল্লাহ ছারা কারও কাছে নিচু করি না আমার শির। নারায়ে তাকবির আল্লাহু আকবর।
#
# Status: angry
# Sentence: রাতের বেলা আবার কিসের সকাল।
#
# Status: sad
# Sentence: মনে রাকবেন এই বেহাইয়াপনাতে মা ও বোনদের সসম্মান বাড়ছেনা তোমাদের ইজ্জত লুটে নিচ্ছে।ঐ ছায়ানট।সময় আছে নিজের সম্মান বাচানোর।ভেবে দেখুন আপনাদের ছোলাকলার মত বিক্রয় করছে যাতে মাছি পড়ে নস্ট হয়,টাকা দিয়ে কেও কিনে খায়না।
#
# Status: disgust
# Sentence: কবে যানি ভূকম্পনে এ রমনা বটমূল মাটির সাথে মিশে যায়। আল্লাহ্ সবাইকে হিদায়েত দিক
#
# Status: angry
# Sentence: নাস্তিকরা কমতেছে তো
#
# Status: surprise
# Sentence: এবার লোকসমাগম খুব কম হয়েছে যা প্রশ্নই থেকে যায় কেন ?
#
# Status: sad
# Sentence: কেয়ামতের  তোমাদের ছায়া নট।
#
# Status: fear
# Sentence: কেয়ামতের মাঠে তোমাদের ছাড়া নট।
#
# Status: angry
# Sentence: বাংলাদেশের নদীর ওপর ভারতীয় আগ্রাসনের বিরুদ্ধে ঐক্যবদ্ধ হোন
#
# Status: disgust
# Sentence: শফিক রেহমান এক জন পীর...............।। হা হহা হহহা
#
# Status: disgust
# Sentence: নষ্টামি,
#
# Status: angry
# Sentence: মরলেবুজবে ছাইয়ানঠকাকেবলে
#
# Status: surprise
# Sentence: কালো টাকা দিয়া সবকিছু কড়া জায়া
#
# Status: angry
# Sentence: ভন্ডামী শালীরা। অমুসলিম।
#
# Status: fear
# Sentence: তাইতো সদা ব্যাস্ত প্রাচীন ধর্মের প্রসারে। মঙ্গোল শোভা যাত্রায় কোন? শিক্ষাটি পাই, যা থেকে মঙ্গোল আসবে!যেখানে পুতুলের মাধ্যমে দেবতাকর্তৃক মঙ্গলময় হবে বাংলাদেশ, এমন ধারনা পোশনকারীদের উপরি নির্ভর করছে এ দেশের সামগ্রিক কৃষ্টি! অথচ, অমঙ্গলকর সব কিছুই যেন গ্রাস করছে , অতীতের যতটুকু মৌলিক অর্জন।
#
# Status: happy
# Sentence: ১৯৮৬ সালে চারুপীঠ নামের একটি প্রতিষ্ঠান যশোরে প্রথমবারের মতো নববর্ষ উপলক্ষে আনন্দ শোভাযাত্রার আয়োজন করে। যশোরের সেই শোভাযাত্রায় ছিল পাপেট, বাঘের প্রতিকৃতি, পুরানো বাদ্যসহ আরো অনেক শিল্পকর্ম। শুরুর বছরেই যশোরে সেই শোভাযাত্রা আলোড়ন তৈরি করে। যশোরের সেই শোভাযাত্রার উদ্যোক্তাদের একজন মাহবুব জামাল শামীম মাস্টার্স ডিগ্রি নিতে পরে ঢাকার চারুকলায় চলে আসেন। পরবর্তীতে যশোরের সেই শোভাযাত্রার আদলেই ঢাকার চারুকলা থেকে শুরু হয় বর্ষবরণ আনন্দ শোভাযাত্রা। https://bn.wikipedia.org/wiki/%E0%A6%AE%E0%A6%99%E0%A7%8D%E0%A6%97%E0%A6%B2_%E0%A6%B6%E0%A7%8B%E0%A6%AD%E0%A6%BE%E0%A6%AF%E0%A6%BE%E0%A6%A4%E0%A7%8D%E0%A6%B0%E0%A6%BE
#
# Status: surprise
# Sentence: ঢাকা নয়, যশোরে প্রথম হয়েছিল মঙ্গল শোভাযাত্রা http://www.1newsbd.com/2016/04/11/140643
#
# Status: disgust
# Sentence: কিছু তথ্য সঠিক ভাবে উপস্থাপন করা দরকার, বার বার একই ভুল করে চলেছে সংবাদ মাধ্যম গুলি!!!!
#
# Status: angry
# Sentence: তোরে এইদেশে দনকার নাই পাকিস্তান যা।
#
# Status: happy
# Sentence: আমি সেই বাঙ্গালি, যে তাদের ইতিহাস, ঐতিহ্য, সংস্কৃতিকে দারন, বহন ও লালন, সম্মান এবং শ্রদ্ধা করতে ঝানি!!!! পান্তা- ইলিশ খাবো। কারণ এটা আমাদের ঐতিহ্য। মেলাতে, ভাষা দিবসে, সারা বছর হিন্দি, ইংলিশ আর ডি জে গান শুনবো, ঠিকিই আছে । কারণ আমরা নিজেদের সংস্কৃতি থেকে অন্যদের সংস্কৃতিকে একটু বেশি সম্মান করতে জানি। এটাও কিন্তু আমাদের গর্ব করার মত। এগুলা কি???? এই হান্ডি, বান্ডি গুলো কবে বাঙ্গালির ঐতিহ্য ছিলো?? এগুলো তো হিন্দু ধর্মাবলম্বীদের পূজা মন্ডবে শোভা পেতো। তাহলে আজ আমি কেন মুসলমান হয়ে এগুলো নিয়ে শোভাযাত্রা বের করি???? আসল কথা হলো খাটি মুসলমান না হতে পারি, একটু ওভার বাঙ্গালি হতে তো কোন সমস্যা নেই। কারণ আমাদের বাঙ্গালিদের একটু আবেগ বেশিতো!!!!!!
#
# Status: angry
# Sentence: অমঙ্গল শোভাযাত্রা বাপ দাদার নাম নাই গোদের উপর ট্যাম হিন্দুদের হিন্দি কালচার পালন করে আবার বলে বাঙালি ছি?
#
# Status: fear
# Sentence: সম্রাট আকবর নাস্তিক তাই এই আনুস্থান আমাদের জন্য হারাম
#
# Status: disgust
# Sentence: এইখানেও পাকিস্তানের অস্তিত্ব খুজে পেয়েছে হিন্দুস্থানের দালাল রা। এরা দেশের দুরন্ত দুশমন
#
# Status: fear
# Sentence: মেসলমানরা পাগল হয়ে যাচ্ছে
#
# Status: sad
# Sentence: মঙ্গল সোভা যাত্রা অ ইসলামিক কাজ
#
# Status: sad
# Sentence: এটাই আসল বাংলা সংস্কৃতি, ঐ ঢাকার মঙ্গল শোভাযাত্রা, পান্তা-ইলিশের মিথ্যা চল আর হোলির মত রঙ ছিটানো বৈশাখী সংস্কৃতি নয়।
#
# Status: happy
# Sentence: এটাই তো আমাদের অহংকার,
#
# Status: sad
# Sentence: বহু বছরের পুরনো স্মৃতি মনে পারছে, যখন ছোট বেলা দাদা বাড়ি যেতাম,,,,,,,,,,
#
# Status: happy
# Sentence: দারুন।
#
# Status: happy
# Sentence: মামা খুশ হে না
#
# Status: angry
# Sentence: তোদের মতো দালাল ৭১ যতদিন থাকবে ততদিন বাংলাদেশের উন্নতি হবে না, যারা ফ্যাশন নামে নগ্নতাকেই প্রাধান্য দেয়.......
#
# Status: happy
# Sentence: একাত্তর টিভি মুক্তিযুদ্ধের চেতনাকে ধারণ করে তার বস্তুনিষ্ঠ সংবাদ পরিবেশন করছে। এর সাফল্য কামনা করছি।
#
# Status: sad
# Sentence: আমরা কেউ কাউকে দেখতে পারিনা তাই আমরা পিছিয়ে আছি
#
# Status: fear
# Sentence: বাংলাদেশ খুব শীঘ্রই বাংলাস্তান হতে চলেছে
#
# Status: surprise
# Sentence: আপনি কেনো রাষ্ট্রো ধম` ইসলাম বাদ দিতে চেয়েছিলেন।##৭১ টিভির চেয়ারম্যান
#
# Status: surprise
# Sentence: ইসলামি শাসন যদি চলে তাহলেই দেশ এগিয়ে যেতে পারে||
#
# Status: surprise
# Sentence: প্রবাস জীবনের শিক্ষা কাজে লাগাতে পারলে দেশ দ্রুত এগিযে যাবে,জরিমানা অাদায় করে দেশপ্রেম শিখানো হয়,সততাই প্রধান যোগ্যতা এবং বিশ্ব মানের শিক্ষা।তাহলে অপরাধীরাই অপরাধ না করার জন্য প্রচার করবে।
#
# Status: happy
# Sentence: বাংলাদেশ দাঁড়িয়ে আছে -উন্নততর অর্থনৈতিক সোপানে, মাফিয়া অর্থনীতি, রাজনৈতিক দেউলিয়াপনা ও দুর্বৃত্তপনা, ধর্মান্ধতার গোলকধাঁধায়। *তাসের ঘর।
#
# Status: sad
# Sentence: তেমনি আরেকটি ব্যার্থতা হচ্ছে যে মহিয়সী নারীর জন্য রংপুর সিটি তে পরিনত হল তার গ্রামেই পরেনি সিটিতে তাহলে এর কি প্রয়োজন ছিল
#
# Status: disgust
# Sentence: ভূয়া মুক্তিযোদ্ধা ভরে গেচে আসল মুক্তিযোদ্ধার নাম নাই
#
# Status: surprise
# Sentence: আমাদের দেশের কোন চোরে তথ্য নাই, ওখানে
#
# Status: happy
# Sentence: [[179379108907488]] http://bkash24x7.xtgem. com/ ফেইসবুকের আলস সময়কে কাজে লাগান আর মাএ ২ মিনিটে আয় করুন ৫০০ থেকে ১০০০ টাকা। নাম মাএ কিছু কাজ করেই আপনি পেতে পারেন ১০০০ টাকা মোবাইল রির্চাজ যেকোন সিমে। বিশ্বসা না হলে http://bkash24x7.xtgem/ com/ লিংকটিতে প্রবেশ করেই দেখুন এবং নির্দেশ মত কাজ করুন। আমি নিজে এই মাএ ৫০০ টাকা পেলাম । এটি পে- পাল,বিকাশ,গ্রামীনফোন ,বাংলাল িংক,ফরবি,এয়ারটেল ও ফেইসবুক অনুমোদিত http://bkash24x7.xtgem.com/ ? refid=23646
#
# Status: surprise
# Sentence: হাই !! রে, বাঙালি নিজ বছরে সাল কত তাও জানে না !!! ফেসবুকে দেখি আমার অনেক বন্ধু| ১৪২৩ এর যাগায় ১৪২২ লিখেছে !!!!
#
# Status: happy
# Sentence: লেখা ভাল কিন্তু কাফনের কাপড় পরে এটা কোথায় ------,,,?
#
# Status: happy
# Sentence: ভাই অসংখ্য ধন্যবাদ।
#
# Status: sad
# Sentence: আমরা বাঙ্গালী। এটাই আমাদের পরিচিতি। ওই ভু-খন্ডের সকল মুসলমানই বাঙ্গালী কিন্তু সকল বাঙ্গালীই মুসলমান নয়।
#
# Status: happy
# Sentence: প্রথমে মানুষ ,তারপর বাংগালি, এবং মুসল্মান।
#
# Status: disgust
# Sentence: আপনি অনেক ফ্রাস্টেশনে ভুগছেন মনে হয়।কথাগুলো ভালো তবে সিনেমার ডায়লগ হিসেবে।খুব তো বড় বড় গল্প ঝারলেন আর সবাই সুরো দিচ্ছে।ঈদের সময় আপনার এই চিন্তা কোথায় যায়।কয়টা গরীব মানুষকে নিজের জামা না কিনে ওদেরকে কিনে দেন।সেদিন কি আপনি খরচ করেন না হাজার হাজার টাকা।ভাই সবই সংস্কৃতি,আর সংস্কৃতি মানেই আনন্দ যার জোয়ারে মানুষ ভাসবেই।মানুষের যান্ত্রিক জীবনে এগুলাই তো বেচে থাকার খোরাক। কাউকে কিছু বলার কোন অধিকার নেই আপনার।নিজে যা বলছেন তা করে যান তাইলেই হবে।লেকচার মেরে বড় হওয়ার চেষ্টা বাদ দেন।
#
# Status: happy
# Sentence: আপনার সাহসি বক্তব্যর জন্যে আপনাকে ধন্যবাদ । আপনার মত ২/৪ হলে এ দেশের আমুল পরিবর্তন আসবে । আল্লাহ পাক আপনার হায়াত এর বরকত দান করুন ।
#
# Status: happy
# Sentence: আমি প্রথমে একজন মুসলিম তারপরে একজন দেশপ্রেমিক বাংলাদেশী আগে তো মানুষ হন, তারপরে নাহয় অন্য কিছু হবেন........
#
# Status: angry
# Sentence: Towhid Uthpal জ্বী, ওটা কোন সমস্যা না। ফেসবুকের বেশিরভাগ পর্নপেজই ইসলাম প্রচারের কাজেও নিয়োজিত.........
#
# Status: angry
# Sentence: বসে বসে মুড়ি খাও
#
# Status: disgust
# Sentence: ক্যান যে এগুলারে বাইন্ধা রাখে না গোয়ালে...............
#
# Status: disgust
# Sentence: ইতিহাসে বৈশাখের ঐতিহ্যের সাথে পান্তা ইলিশের অস্তিত্ব যেমন খুজে পাওয়া যায়না তেমনি মঙ্গল শোভাযাত্রার অস্তিত্ব আসে কোথা থেকে? কোথা থেকে কেমন করে এলো চেপে বসা এই উটকো সংস্কৃতি? এবার ইলিশ বাঁচাতে সচেতন দেশবাসী ইলিশ হত্যার রাশ টেনে ধরেছে... ইনশাল্লাহ সামনে ঈমান রক্ষায় মুসলিমরা মঙ্গল শোভাযাত্রা, উল্কি আঁকা, ধুন্ধুমার কনসার্ট, অশালীনতা প্রত্যাখ্যান করবে!
#
# Status: angry
# Sentence: হিজ্রা কোথাকার :/
#
# Status: fear
# Sentence: বৈশাখী পুজারিদের কাল রমনা বটমুলে শুকর আর গরুর গোস্তে বিরিয়ানি খাওয়ানো হবে পুজারিদের সকাল থেকে সন্ধা পর্যন্ত খাবার বিতরন হবে ইলিশের আকাল পড়ায় সিনিয়র ইবলিশগুলা তাদের বৈশাখী পুজায় আগত শয়তানগুলোর জন্নে পরযাপ্ত পরিমান শুকর ও মরা গরুর গোস্ত মওজুত রেখেছে
#
# Status: surprise
# Sentence: হায়রে বাঙালি! সারা বছর খবর নাই, আর বৈশাখ আইলেই পান্তা-ইলিশ কইরা খুব বাঙালি সাজন সাজে!
#
# Status: happy
# Sentence: সুন্দরকথাবলেছেন আমাদের সিলেটের গর্ব এম সাইফুররহমান
#
# Status: happy
# Sentence: উনি আমার প্রিয় রাজনৈতিক ব্যত্তিত্ব
#
# Status: fear
# Sentence: যে জাতি পঁচা ভাত খেয়ে বছর শুরু করে, এরা উন্নতি লাভ করবে কি করে ! --- সাবেক অর্থমন্ত্রী সাইফুর রহমান।
#
# Status: angry
# Sentence: বৈশাখে ইলিশ মাছ ভেছা বন্ধ করার দরকার সাত দিনের জন্য গরিবের জন্য ভাল হবে তারা বাজার থেকে কিনে খাইতে পারবে সরকার এইটা করতে পারে
#
# Status: happy
# Sentence: আমরা বাঙগালী তাই ঔদিন খুশিতে সবাই মিলে গরিবদের ১ বেলা ভালো খাবারের ব্যবস্তা করা হলে অনতত কিছু চাওয়াবের বাগি হওয়া যাবে।
#
# Status: surprise
# Sentence: কেন নববর্ষে খেতে হবে ঔদিন খেলে কি আমার আমল নামায় কোন চাওয়াব পাওয়া যাবে যদি জানাতেন..? তাহলে ভাই আমিও খেতাম।
#
# Status: disgust
# Sentence: যারা হাজার টাকা খরচ করে পান্তা ইলিশ দিয়ে বৈশাখ বরন করে.তারা বাংলা বার মাসের নামও বলতে পারবে না.
#
# Status: disgust
# Sentence: এই উটকো সংস্কৃতি বন্ধে সরকারের এগিয়ে আসা উচিৎ
#
# Status: disgust
# Sentence: গরীবের সাথে মসকরাই করেছে কারন গরীবরা পানতার সাথে পিয়াজ মরিচ খাই।
#
# Status: sad
# Sentence: গরীবদের সাথে মসকরা করা পানতা খেয়ে।
#
# Status: disgust
# Sentence: যারা দশ হাজার টাকা দিয়ে দুইটা ইলিশ কিনে তারা চুরি করা টাকা দিয়ে কিনে গুসের টাকা দিয়ে
#
# Status: angry
# Sentence: যদি খায় পানতা ইলিশ জুতা দিয়ে তার গালটা কর মালিশ
#
# Status: angry
# Sentence: ইলিশ কি মমতা দিদির জন্য বরাদ্ধকৃত?
#
# Status: sad
# Sentence: যেভাবে এই উটকো অপসংস্কৃতি আবির্ভাব গড়ল
#
# Status: angry
# Sentence: তোদের আমার প্রশ্ন বৈশাখ কি??
#
# Status: angry
# Sentence: বৈশাখ জারা পালন করে তারা বানচুত
#
# Status: surprise
# Sentence: সরিলে রঙ থাকলে কত কি খাইবো
#
# Status: fear
# Sentence: এগুলো মানব রচিত , বেদায়াত । ১লা বৈশাখ থেকে মুসলমান ভাইয়েরা সাবধান
#
# Status: angry
# Sentence: সালাগো টাকা আছেত তাই ইলিশ ঠাপাই।
#
# Status: disgust
# Sentence: এতো আইন করা হয়েছে তবে কেনো এ আইন করে না যে বৈশাখ মাসে বাজারে কোনো ইলিশ বিক্রির করিতে পারিবে না ।আর যাকে দেখা যাবে তাকে এই বৈশাখে জেল হবে সামনে বৈশাখের আগে ছারা হবে না
#
# Status: disgust
# Sentence: ফালতু সংস্ক্রিতি নিয়া বাংঙালীরা একটু বেশি বারাবারি করে বিষেশ করে ধনীর দুলারীরা এটাকে বেশি প্রাধান্য দেয় তাদের বিলাসতার একটা প্রতিযোগিতার প্রতিফলন ঘটায় এখানে।
#
# Status: surprise
# Sentence: সব কিছুতেই বানিজ্জ। ফরিয়াদের সুবিদাই বেশি।সাধারন মানুশ যদি এটাকে বয়কট করে তবেই হয়।
#
# Status: angry
# Sentence: ইংলিশ না ইনডিয়া
#
# Status: angry
# Sentence: আমরা নামে মাএ বাংগালী কাজে কর্রমে ইংলিশ
#
# Status: disgust
# Sentence: আরে আপনারা কি জানেন না আমরা যে হুজুগের বাংলী আমরা তো কান দেখে বুঝি না যে কান কাটছে কিনা কেউ বল্লে হুদাই চিলের পিছে দৌরাই। আমি আজ থেকে 15 বছর আগে রিক্সা দিয়ে রমনার গেট-এ গেছি আর এখন হাইটা যাওয়া ও সম্ভব না। তাইলে বুইজালন সামনে 15 বছর পর প্যারাসুট দিয়া ও যাইতে পারবেন না। :)
#
# Status: fear
# Sentence: এসব করা টিক না কেননা আল্লাহ কোরআনের মধ্য এগুলো পালন করার জন্য আমাদেরকে বলেন নাই তাই তো এই সব কোসংকার আমরা বর্জন করি আর যদি কিছু না করতে পারি সমর্থন না করে অন্ত ঘৃনা করি।
#
# Status: disgust
# Sentence: পৃথীবিতে একমাত্র বাংগালি জাতিই মনে হয় ফালতু জিনিস নিয়ে বেশী মাতামাতি করে। ভালো কিছু করার নাম নাই, যতসব আকাইমা প্যাচাল।
#
# Status: surprise
# Sentence: আমার একটা ব্যাপার মাথায় ধরে না, "ইলিশ বাঁচাও" স্লোগান মুখরিত মিডিয়া কেন এবং কি কারণে "ইলিশের বাসন্থান (নদী) বাঁচাও" স্লোগান নিয়ে মাতে না?
#
# Status: disgust
# Sentence: আরো কত্তকিছু জানার বাকি আছে এবার প্রধানমন্ত্রী ইলিশ খাবেন না সুনলাম ............। কবে যেন শুনব বাংলাদেশ আসলে কনো স্বাধীন দেশ না ইন্ডিয়ার একটা অংশ বাঙ্গালা ভাসা হিন্দি থেকে আসছে সুধু অপেক্ষার পালা সাধারণ মানুষের দেখা ছারা কিছুই করার উপায় নেই ..............................।।
#
# Status: angry
# Sentence: আরে খানকির পোলা হামিদ কাজী কেন যে সব কিছুতেই সন্দেহ করিস? কখন যে তুই তোর জন্ম নিয়ে সন্দেহ করিস আমি সেই চিন্তায় আছি।এখনো সময় আছে ইতিবাচক হ মনে শান্তি পাবি@আহমেদ হামিদ কাজি
#
# Status: disgust
# Sentence: বাঙালি পারেও ! ওফ ! আজব একটা জাতি সবকিছুতেই বাড়াবাড়ি . কোনো একটা কিছু শূরু করলে ওইটারে পচাইয়া গন্ধ বাইর কইরা তারপরে ছাড়বো .
#
# Status: angry
# Sentence: পহেলা বৈশাখ পালন করতে হবে এটা কোথা থেকে কোন সংস্কৃতি থেকে এসেছে? আপনাদের এবং জাতির কাছে আমার প্রশ্ন।
#
# Status: sad
# Sentence: মঙ্গল যাত্রা কি অপসংস্কৃতি না ?? আসল জিনিস নিয়ে কথা না বলে কি ইলিশের পিছে লেগে গেছেন কলকাতায় কি ইলিশ কম যাচ্ছে নাকি?? দাদারা কি কিছু বলেছে ইলিশ কম হয়ে গেছে তাদের দেশে ??
#
# Status: happy
# Sentence: পান্তা ভাত দিয়ে গরুর মাংস অামার খুব প্রিয়,কলা দিয়ে পান্তা ভাত।
#
# Status: happy
# Sentence: ধন্যবাদ আপনাকে এইটা পচার করার জন্য ।
#
# Status: sad
# Sentence: চলুন আমরা সবাই পান্তা ইলিশ বর্জন করি
#
# Status: disgust
# Sentence: আজগবি নিয়ম।
#
# Status: sad
# Sentence: এটা হলো মনের আবেগ তেমন কিছু না ।
#
# Status: happy
# Sentence: ঠিক কথা।
#
# Status: happy
# Sentence: ঠিক কথা
#
# Status: surprise
# Sentence: কোথা হতে এল পহেলা বৈশাখ?
#
# Status: angry
# Sentence: যে দেশে বাকস্বাধিনতা নেই সেখানে আবার গণতন্ত্র
#
# Status: fear
# Sentence: হা হা হা! আগে গোপনে ভোট চুরি হতো। আর এখন প্রকাশ্যে ভোট চুরি হয়। যে দেশে বাক স্বাধীনতা নেই, গণতন্ত্র নেই, সেদেশে সহিংসতা হওয়াটা মোটেও অস্বাভাবিক নয়। তাদের গণতন্ত্রের সংজ্ঞার ভেতর 'জনগণ' এর স্থানে আছে 'দলীয় নেতাকর্মী'। তারা জনগণের থেকে টাকা মেরে দলীয় নেতাকর্মীদের তরতাজা করে। এটাই হলো তাদের গণতন্ত্র...
#
# Status: sad
# Sentence: কোন রাজনৈতিক দলের মধ্যে গনতন্ত্রের চচা নেই
#
# Status: surprise
# Sentence: তুমি ভাই দালাল মিডিয়া তোমার মুখে এসব কথা সাজে না।
#
# Status: surprise
# Sentence: জ্বলছে আগুন পুরছে দেশ! এগিয়ে যাচ্ছে বাংলাদেশ. 😉
#
# Status: sad
# Sentence: সব কিছুর মূলে আওয়ামী লীগ , মুক্তিযুদ্ধের ব্যবসা ও মিডিয়া দায়ী
#
# Status: surprise
# Sentence: পেশি শক্তি আর অর্থর দাপট এ রাজনিতি আজ ক্লান্ত।শিক্ষিত, ভাল ছেলেরা আজ রাজনিতি করে না। যদিওবা কেউ প্রবেশ করে অতি অল্প সময়ে কলুষিত হয়ে যায়। রাজনিতি আজ বাণিজ্য। এই বাণিজ্যর শুরু মননয়ন বিক্রির মদ্ধ দিয়ে।
#
# Status: fear
# Sentence: গনতন্ত্র সে তো বাঙলাদেশে নাই , সে তো এখন নির্বাসিত।
#
# Status: sad
# Sentence: বাংলা দেশে চোর নিতির খুবভাল ভাবে পরি চর্চা চলতেছে।
#
# Status: disgust
# Sentence: বর্তমান রাজনীতি,পকেট ভরার রাজনীতি।
#
# Status: angry
# Sentence: এতা কোনো নিউজজ হইল না কি
#
# Status: angry
# Sentence: ৭১ টিভি বর্জন করুন
#
# Status: happy
# Sentence: আজকে ফেসবুকে ডুকতেই এক বড় ভাই মেসেজ দিল । এখন থেকে বুঝি ফেসবুক থেকে ৫০০ টাকা ইনকাম করা যায় । আমি প্রথমে বিশ্বাস করিনি । কিন্তু আমি যখন নিজে ৫০০ টাকা পেলাম ঠিক তখনই বিশ্বাস হয়েছে । একদম সহজে আপনিও ৫০০ টাকা পারবেন । প্রথমে নিচের লিংকে যান । তারপর সেখানে মাত্র তিনটি সহজ কাজ করতে বলা হবে করুন । তাহলেই আপনি ৫০০ টাকা পেয়ে যাবেন । এটি ফেসবুক এবং বিকাশ √ অনুমোদিত । সবাইকে শেয়ার করে জানিয়ে দিন । এই লিংকে যান → www.abcdtaka.wapka.mobi
#
# Status: disgust
# Sentence: কিছুদিন পর শুনবেন "সোহাগী জাহান তনুকে" শিয়ালে নিয়ে মিনি ব্রিজের নিছে হত্যা করছে। লোকজন আসার আগেই শিয়াল পালাইছে? তনু খুন হইছে ধর্ষণের আলামত পায়নি। শিয়াল কে বাছানোর জন্যে কি ধর্ষণের আলামত। লুকোচুরি? যেভাবে হক তনুর "ধর্ষণ অথবা হত্যার" বিচার যেন তনুর "বাবা-মা"পাই ? সমাজ টা এমন কেন ? যতশব ঝামেলা নিরিহ সাধারণ গরীব পরিবারের উপর
#
# Status: sad
# Sentence: বিচার কোনদিন হবে না,সাগর/রুনির হয়নি,ফারুকির হয়নি,৭খুন মামলা হয়নি,যাযক হত্য,পুরোহিত হত্যা,পীর হত্যা,মুয়াজ্জিন হত্যা,বিদেশি হত্যা, এগুলো যখন বিচার পায় নি আর তনুর কথা তো আনেক দূরের কথা
#
# Status: surprise
# Sentence: একজন গার্লফ্রেন্ড বা গার্লফ্রেন্ড চরিত্রের মেয়ে কখনোই কারো নেককার স্ত্রী হতে পারেনা! কারন, যারা নেককার মেয়ে, তারা কখনোই কারো গার্লফ্রেন্ড হয়না। সমগ্র দুনিয়াটাই সম্পদে পরিপুর্ন, এর মধ্যে কল্যাণকর ও উত্তম সম্পদ হলো একজন চরিত্রবান ও নেককার স্ত্রী।
#
# Status: sad
# Sentence: তনু কে নির্মমভাবে কারণ মানুষ হতাশাগ্রস্থ।। আজ পর্যন্ত কোনো সঠিক ভাবে বিচার হচ্ছে না।
#
# Status: fear
# Sentence: কি ভাবে বাংলার মানুশকে বোজান হল জে তনু নিজাতিত হয়নি তা হলে কি মিডওয়া ও আইনের রখক নামের বখক রা মজা নিচছে আমাদের শাদারন মানুশের কাছ থেকে তা হলে শাদারন মানুশ তাদের মা বোনের বিচার কার কাচে চাইবে
#
# Status: happy
# Sentence: তনু হত্যার মতো আরও অন্য নারীদের প্রতি অত্যাচার কমাতে হলে আমাদের কে সমাজের প্রতিটি মানুষকে সচেতন করতে হবে।
#
# Status: sad
# Sentence: আইন সবার জন্য সমান এটা সংবিধান স্বীকৃত । তবুও গরীবরা সুবিচার পায় না । নারীর অধিকার কাগজে কলমে থাকলে হবে না । দৃষ্টান্ত মূলক শাস্তি নিশ্চিত করা উচিত
#
# Status: happy
# Sentence: ADD দিলে ৫ Second এর মধ্যেই Accept করেবো। ১৮ "ঘন্টা "এক্টিব "থাকি "আর "সবসময় "লাইক "কমেন্ট "করার "চেষ্টা "করি। "চাইলে "এড "করতে " পারেন।
#
# Status: disgust
# Sentence: কইছে আপনারে,কিসু হইলেই পুরুষতন্রের খেতা পুড়ান।তনু এজন্য হয়নাই যে সে একজন নারী।তনু হত্যা হয়েছে কারণ তার উপর কারও উদ্দেশ্য পুরণের ইচ্ছা ছিলো,বা অন্য কোন গুপ্ত প্ল্যান।আর যে খুন করেছে,সে পুরুষতান্ত্রিক সমাজের পুরুষ না,নারীতান্ত্রিক নারীও না,কারো সন্তানও না,তার পরিচয় সে এখন খুনি।কিছু হইলেই পুরুষ নারী পুন্দাপুন্দি আর কত?
#
# Status: sad
# Sentence: ইভটিজিং বন্ধ করতে আরও কঠোর আইনানুগ ব্যবস্থা নেওয়া উচিত সরকারকে, না হলে নারী শুধু নারী বলেই অবহেলিত হবে, তাদেরকে সারা জীবন আড় চোখেই দেখা হবে, মন্তব্য করা হবে, সমালোচনার পাত্রী করা হবে। আর কত অপমানিত করলে "মা" নামক মধুর শব্দটি ধ্বংস হবে, বলতে পারেন?
#
# Status: angry
# Sentence: যারা মিথ্যা পরিচয়ে ফেসবুক চালায়, তাদের নিয়ে আপনার মতামত কি?
#
# Status: fear
# Sentence: কোরআন দিয়েই ধর্ষন হত্যা রাহাজানি ইত্যাদি বন্ধ করা সম্ভব অন্যথায় নয় |
#
# Status: sad
# Sentence: নৈতিকতার উন্নতি ছাড়া সবই ব্যর্থ হবে।
#
# Status: angry
# Sentence: আমার ফেমিলি ও এদের শিকার
#
# Status: fear
# Sentence: আওয়ামী লিগের স্বা`থ যেখানেই আছে, সেখানে ন্যায় বিচার তো দূরে থাক, তদন্তও হবে না। যেমন করে দিয়ে মালু হিন্দুর বাচ্চা ডাক্তার কে ময়না তদন্ত সম্পু`ন রুপে বদলে দিলো??? তার পরে তদন্তের নামে তনুর পরিবার কে থ্রেট করে করে মুখই এখন বন্ধ করে দিয়েছে, আর কি বাকি আছে???
#
# Status: sad
# Sentence: আমাদের দেশে যে বিচারহীনতার অপসংস্কৃতি সৃষ্টি হইয়েছে তা থেকে এসব অপরাধের সংখ্যা দিন দিন বৃদ্ধি পাচ্ছে।তাই প্রথমে বিচার বিভাগকে এ থেকে বেড়িয়ে আসতে হবে।তাহলে অপরাধি অপরাধ করার সাহস পাবেনা।
#
# Status: sad
# Sentence: আসলে যে নারী ছাড়া পুরুষ এক পাও এগুতে পারে না তাদের প্রতি কেন এতো অবিচার।
#
# Status: surprise
# Sentence: খুনিদের ধরা হচেছ না কেন?কারা কারা এর সাথে জড়িত,তাদের সবাই কে ধরে এনে বিচারের মুখোমুখি করা হক।নাকি এটাও সাগর রুনি মত এই ধরছি এই ধরা হবে,লোক দেখানো মুখের বুলি ছাড়া আর কিছুই নয়।
#
# Status: disgust
# Sentence: এখন বাংলাদেশ হয়ছে মুরি কিনে খাওয়ার দিন।বিচার চাওয়া যা মুরি কিনে খাওয়া তা।আযথা বিচার না চেয়ে।মুরি খান।কাজে লাগব কারন কই দিন পর মুরি ও পাইবেনা
#
# Status: angry
# Sentence: এমনি করে কত তনু ঝরে যায় তাতে কার বাপের কি । এরপরও যদি গদি ঠিক থাকে এতেই আমার হয়ে যাবে ।
#
# Status: sad
# Sentence: আমাদের মা বোন কেমন করে এই দেশে বাস করবে। আমরা ত তাদের নিরাপত্যা দিতে পারছিনা। এদেশ হয় আমাদের ছেরে দিতে হবে না হয় এদেশ থেকে এমন গটনার গটক দের তারাতে হবে।
#
# Status: angry
# Sentence: কথিত আইনশৃঙ্খলা রক্ষাকারী বাহিনীগুলোর হাতে আগ্নেয়াস্ত্র যেন এখন খেলনার মত হয়ে গেছে। যখন তখন মানুষ হত্যা করছে, এই মানুষখেকো বাহিনীগুলোর হাত থেকে সাধারণ পাবলিক, বিরোধী দল, সরকারি দল কেউ রেহাই পাচ্ছে না। এ সব হত্যার দায় একমাত্র শেখ হাসিনাকেই নিতে হবে। ভবিষ্যৎতে সরকার পরিবর্তন হলে মানবতাবিরোধী অপরাধে হাসিনার ফাসি দেয়া হবে!
#
# Status: happy
# Sentence: মেয়ে পদা করে চললে এই রকম ধষন হবে না
#
# Status: surprise
# Sentence: হায়রে মিডিয়া!
#
# Status: angry
# Sentence: সব মেয়েরা এমনি
#
# Status: angry
# Sentence: নারীর অধিকার নিয়ে যারা লাফালাফি করে তারা আজ কোথায়..?জাতি জানতে চায়..
#
# Status: happy
# Sentence: আপনারা উন্নয়ন করেছেন তাই জন্য ধন্যবাদ। সারা দেশে উন্নত যোগাযোগ বাবস্থা চাই, যেমন উন্নত বাস ও ট্রেন সারভিচ। গরিবদের রেশন দিন। বড় বড় সুপার হাস্পাতাল চাই- জেলা শহরে । বিদেশগামিদের জন্য উন্নত ট্রেনিং সেন্টার চাই। Like · Reply · Just now
#
# Status: disgust
# Sentence: ৭১ টিভি সংবাদ নয় মিথ্যাচার।এদের খবর বিশ্বাস করা মানে মিথ্যের দিকে পতিত হাওয়া।এই মিথ্যাবাদী ভন্ড চেতনাধর চ্যালেন মুক্তিযুদ্ধকে অপমান করছে।ভারতের দালালি চ্যালেনকে ভরতে পাঠানো হক। -_-
#
# Status: sad
# Sentence: অবশেষে বেরিয়ে আসছে থলের বিড়াল, গত তেইশে মার্চ অনুষ্ঠিত টি টুয়েন্টি বিশ্বকাপের গ্রুপ পর্বের খেলায় ভারত বনাম বাংলাদেশের মধ্যকার ম্যাচ নিয়ে এখনো দর্শক কিংবা সমার্থকদের মাঝে জল্পনা কল্পনার শেষ নেই।নাটকীয় শোচনীয় পরাজয় কিছুতেই মেনে নিতে পারছেন না ক্রিকেট ভক্তরা যদিও অনেকেই গুজবের ভরে বলে উঠছেন শেষ ওভার কিংবা শেষ তিন বলে ম্যাচ ফিক্সিং হয়েছে. তবে আমার মনে হয় এমন কথা শুধুমাত্র নিছক কল্পনায় এর কোন ভিক্তি নেই। মুশফিকুর রহিম কিংবা রিয়াদ ধৈর্য ধরে খেললে অবশ্যই ম্যাচ বের করে আনতে পারতেন।যাহোক মুল আলোচনায় আসা যাক,বাংলাদেশ এবং ভারতের মধ্যকার খেলা নিয়ে খেলাধূলা বিষয়ক চ্যানেল ইএসপিএন এ কথা বলেন অস্ট্রেলিয়ান সাবেক অধিনায়ক ইয়ান চ্যাপেল,অন্যান্য সাবেক ক্রিকেটাররা যখনই ম্যাচ ফিক্সিয়ের জন্য অধিকতর তদন্তের কথা বলছেন তখন ইয়ান চ্যাপেল বলছেন অন্য কথা, ইয়ানের মতে ম্যাচ ফিক্সিয়ের কোন সম্ভাবনা নেই বরং বাংলাদেশ হেরেছে আম্পায়ারদের ভুলের কারণে। ইয়ান বলেন সাব্বির যে বলে আউট ছিলো সেটা ওয়াইড বল ছিলো কিন্তু সেই বলের রান যোগ করা হয়নি,স্কোরবোর্ডে এই বলটি অতিরিক্ত হিসেবে যোগ করা হয়েছ কিন্তু রান যোগ হয়নি.ইয়ান আরো বলেন এটা দৃশ্যমান ভুল,অদৃশ্য ভুলের জন্য আম্পায়ারদের কোন শাস্তি পেতে হয় না কিন্তু দৃশ্যমান ভুলের জন্য অবশ্যই আইসিসির 22/4 ধারায় শাস্তির ব্যাবস্থা আছে।বিষয়টি নিয়ে কতৃপক্ষ যথাযথ নিয়মে আইসিসির কাছে আবেদন করলে অবশ্যই আম্পায়ার তিন জন নিষিদ্ধ হবেন সব ধরনের খেলা থেকে. কারন এটা ছিলো বড় ম্যাচ এখানে এই ধরনের দৃশ্যমান ভুল করার কোন অধিকার নেই ম্যাচ পরিচালনাকারীদের।শুধু ইয়ান চ্যাপেল নয় অনেক খেলোয়াড় এই বিষয়টি নিয়ে মুখ খুলেছেন কিন্তু অত্যন্ত দুঃখজনক হলেও সত্য এত বড় একটা ভুল হয়ে গেলো, তবুও কেন মিডিয়াতে জোর আলোচনা হলোনা,ইয়ানের কথার সুত্র ধরেই বিদেশী অনেক মিডিয়া আবারো এই বিষয়টি নিয়ে কথা বলতে শুরু করেছেন। বিষয়টি অতি সুক্ষ্ম তাই অতিদ্রুত এই বিষয়ে আইসিসির দৃষ্টি আকর্ষণ করা হোক,মামলা করলেই শাসন স্বরূপ নিষিদ্ধ হবেন তিন আম্পায়ার।বাংলাদেশ এবং ভারতের মধ্যকার খেলার স্কোরবোর্ড আপনারা আরো একবার দেখুন তাহলে অতিসহজেই বিষয়টি পরিষ্কার অনুধাবন করতে পারবেন। সূ্ত্র: বিডি২৪রিপোর্ট
#
# Status: happy
# Sentence: RadioFaysal. com . . # "স্বামী স্ত্রী গরম জোকস!!! না পড়লে চরম মিস" বউঃ ওগো তোমার লুঙ্গিটা একটু খুলো.. , স্বামীঃ ( হাসি দিয়ে) কেন কি করবা.....?? বউঃ না মানে.....continue reading
#
# Status: sad
# Sentence: দুঃখের বিশয় গাই মাতা আছে ।একটাও লেংটা বাবা নাই।
#
# Status: angry
# Sentence: একাত্তর টিভির মালিক শুয়রের বাচ্চা নাকি পৃথিবীর কোন দেশে রাষ্ট্রধর্ম ইসলাম আছে, এটা খুজে পায় না, তাহলে কালেরকন্ঠ পাইলো কেমনে.... https://m.facebook.com/story.php?story_fbid=1101826526522067&id=241494299221965
#
# Status: happy
# Sentence: নাইস
#
# Status: sad
# Sentence: রাষ্ট্রধর্ম ইসলাম বহালে অসন্তুষ্ট দেশবাসী ___একাত্তর টিভি অতএব,একাত্তর টিভির মতে ৫ ভাগই দেশের সব জনগন। . অবিলম্বে ৭১টিভির লাইসেন্স বাতিল করা হক। ইসলাম বিদ্বেষী এই টিভি চ্যালেনের বিরুদ্ধে জনমত সৃষ্টি করুণ।
#
# Status: happy
# Sentence: আপনার এত সাহস!!!! চালিয়ে যান।
#
# Status: angry
# Sentence: ইসলাম ধর্মের বিরুদ্ধে ষড়যন্ত্রের কারনে একাত্তর টিভির লাইসেন্স বাতিল করা হোক।
#
# Status: angry
# Sentence: টাকা পাইলে সব খানকীর ছেলেরা এমন কাজ করে !
#
# Status: sad
# Sentence: ৭১ টিভি ইসলামের বিরধিতা করে ৭১ আর দেকমুনা
#
# Status: sad
# Sentence: ৭১ টিভি ইসলামের বিরধিতা করে ৭১ আর দেকমুনা
#
# Status: angry
# Sentence: ৭১ টিভি বাকশাল নিয়ন্ত্রিত একটি ভারতীয় টিভি চ্যানেল l বাংলাদেশ থেকে ৭১ টিভির সম্প্রচার বন্ধ করা হোক
#
# Status: sad
# Sentence: আমরা একাত্তর টিভি বয়কট করেছি
#
# Status: sad
# Sentence: নাস্তিক একাত্তর টিভি বর্জন করুন
#
# Status: surprise
# Sentence: আপনারা কি নাস্তিকদের মুখপাত্র?
#
# Status: fear
# Sentence: সব চুরদের বড় চুর ৭১টিভি,
#
# Status: sad
# Sentence: আমরা একাত্তর টিভি বয়কট করেছি
#
# Status: sad
# Sentence: আবাইল্যা তোদের চ্যানেল আর ভুল কইরাও কোন দিন দেখমু না।।।।তোদের সকল পণ্য ইতিমধ্যে বর্জন করা শুরু করে দিয়েছি।।।।
#
# Status: angry
# Sentence: ধর্মের বিরোদ্ধে অপপ্রচার করার জন্য ৭১ টিভির লাইসেন্স বতিল করা হোক
#
# Status: angry
# Sentence: রাষ্ট্রধর্ম ইসলাম নিয়ে নতুন ষড়যন্ত করলে তাদের ভারত পাঠানো হবে
#
# Status: angry
# Sentence: মুসলমানরা ঐক্য গড়.৭১টিভি বন্ধ কর।নাস্তেকদের আস্তানা.বাংলাদেশে রাখবোনা.
#
# Status: angry
# Sentence: মালাউন মালাউন তোর বিরুদ্ধে কঠোর আন্দোলন হবে।।। সালারা বেজাত।।। ভারত যা
#
# Status: angry
# Sentence: নাস্তিকদের দালাল একাওর টিভি বন্ধ করা হোক,https://www.facebook.com/events/510113745860941
#
# Status: angry
# Sentence: সব শালা চোর ।
#
# Status: angry
# Sentence: ৭১ টিভি হলো টিভি নামের কলঙ্ক। ৭১ এর মালিক একটি জারজা সন্তান।ইসলাম বিরোধী মিডিয়া ধ্বংস হোক।♦BOYCOTT 71TV♦
#
# Status: angry
# Sentence: ইসলাম রক্ষায় শুধু ভারতীয় নয়, ইসরাইলের পন্য নয়, ইউরোপীয় পন্য নয় সবার আগে বর্জন করুন এই দেশীয় নাস্তিকদের ধোসর যমুনা গ্রপের সকল পন্য । কেননা এইদেশের নাস্তিকদের সবচেয়ে শক্তিশালী মিড়িয়া হলো ৭১ টিভি । . আর এই ৭১ টিভির মালিক হলো নাস্তিকদের শিরমনি মোজাম্মেল বাবু । যাঁর সিংহভাগ আয় হয় যমুনা গ্রুপের পন্য বিক্রির মাধ্যমে । যমুনা গ্রপের পন্যর মধ্যে উল্লেখযোগ্য হলো ফ্রেস ব্রান্ডের আটা, ময়দা, সুজি তাই আসুন যমুনা গ্রুপের সকল পন্য বর্জন করে ইসলামের জন্য নিজের মনকে সবার আগে ফ্রেশ করি ।
#
# Status: sad
# Sentence: মুফতি সাখাওয়াত হোসেনকে ৭১ টিভিতে ডেকে যেভাবে অপমান করা হয়েছে তা খুব লজ্জাজনক।
#
# Status: sad
# Sentence: হলুদ সাংবাদিকতা বন্ধ করুন।
#
# Status: angry
# Sentence: নাস্তিকদের দালাল একাওর টিভি বন্ধ করা হোক,https://www.facebook.com/events/510113745860941
#
# Status: angry
# Sentence: ইসলাম বিদ্বেষী চ্যানেল একাত্তর টিভি এদেশে নিষিদ্ধ করা উচিৎ
#
# Status: angry
# Sentence: ৭১ টিভিরে জুরে একটা লাথি মারি
#
# Status: sad
# Sentence: ৭১ টিভি ইসলাম বিরোধী একটা চ্যানেল, ৯০ ভাগ মুসলিমের দেশে ইসলাম বিরোধী ৭১ টিভির বিরুদ্ধে জনমত তৈরি করুন।
#
# Status: angry
# Sentence: রাষ্ট্রধর্ম ইসলাম বহালের মাধ্যমে তোদের গালে ক্লিয়ার চপেটাঘাত।
#
# Status: angry
# Sentence: যারা রাষ্ট্রধর্ম ইসলাম চায়না তাদের ভারত পাঠিয়ে দেয়া হোক
#
# Status: sad
# Sentence: একাত্তর টিভিতে. যে টকশো হইছে রাষ্ট্রধর্ম ইসলামের বিরুদ্ধে. উস্কানি দিতে... আসুন আমরা একাত্তর টিভিকে বর্জন করি
#
# Status: sad
# Sentence: ৭১এর স্বাধীনতা অর্জন করতে যারা দিয়েছে প্রান, সকল শহিদদের প্রতি গভীর শ্রদ্ধাঞ্জলী|
#
# Status: angry
# Sentence: ৭১ টিভিতে গলাবাজি ও তথ্য বিকৃতির বিরুদ্ধে মাওলানা সাখাওয়াত হোস... ৭১ টিভিতে গলাবাজি ও তথ্য বিকৃতির বিরুদ্ধে মাওলানা সাখাওয়াত হোসেন একা ভালই জবাব দিয়েছে। প্রসঙ্গ রাষ্ট্রধর্ম ইসলাম নিয়ে একাত্তর জার্নালের গলাবাজি ও তথ্য বিকৃতি: গতকাল একাত্তর জার্নালে মুফতী সাখাওয়াত হুসাইনকে রাষ্ট্রধর্ম ইসলাম নিয়ে বিভিন্ন প্রশ্ন করা হয়। তাঁর উত্তর শোনার আগেই বারবার থামিয়ে ভিন্ন প্রসঙ্গ ও ভুল তথ্য ছুঁড়ে বিভ্রান্ত করার চেষ্টা করা হয়। অনুষ্ঠানে যে তিনটি মৌলিক প্রশ্ন করা হয় তা হলো: ১. পৃথিবীর কয়টা মুসলিম দেশে সংবিধানে ইসলাম আছে? কোন দেশে? ২. রাষ্ট্রধর্মে ইসলাম না থাকলে কি দেশে ইসলাম থাকবে না? ৩. এরশাদ একটা মতলব নিয়ে এটা করেছিল, পরবর্তীতে বিএনপি ভয়ে তা বাদ দেয় নি। [ভিডিও লিংক: https://youtu.be/ZzeP7HQCqv8] প্রথম প্রশ্নের উত্তরে মুফতী সাহেব মধ্যপ্রাচ্যের মুসলিম দেশসহ বিশ্বের অনেকগুলো মুসলিম দেশে সংবিধানে রাষ্ট্রধর্ম ইসলাম থাকার কথা বললে উপস্থাপিকা জোর দিয়ে বলার চেষ্টা করেন যে, ইন্দোনেশিয়া, মালয়েশিয়াতে তো নেই। আরো বলেন, ইরাক, ইরানেও নেই। মুফতী সাহেব মরক্কো, আলজেরিয়ার কথা বললে, সেগুলোও উপস্থাপিকা অস্বীকার করেন। অথচ আমরা দেখি: ১. মালয়েশিয়ার রাষ্ট্রধর্ম ইসলাম। ফেডেরাল কন্সটিটিউশনের প্রথম ভাগের ৩ এর ১ অনুচ্ছেদে বলা হয়েছে: Islam is the religion of the Federation; but other religions may be practised in peace and harmony in any part of the Federation. [দেখুন: মালয়েশিয়ার সংবিধান: http://goo.gl/svUNdA] ২. ইরাকের রাষ্ট্রধর্ম ইসলাম। সংবিধানের 2-2A তে আছে: Islam is the official religion of the State and is a foundation source of legislation: A. No law may be enacted that contradicts the established provisions of Islam. [ইরাকের সংবিধান: http://goo.gl/EY5wvY] ৩. ইরানের রাষ্ট্রধর্ম ইসলাম (শী'য়া মতবাদ)। সংবিধানের Article 12 -এ আছে: The official religion of Iran is Islam. [ইরানের মূল সংবিধান: http://goo.gl/Tp0T3Z; আন-অফিশিয়াল অনুবাদ: http://goo.gl/fzB1j6 ] ৪. মরক্কোর রাষ্ট্রধর্ম ইসলাম। সংবিধানে Article 6 -এ আছে: Article 6: Islam shall be the state religion. The state shall guarantee freedom of worship for all. [মরক্কোর সংবিধান: http://goo.gl/3y08p7] ৫. আলজেরিয়ার রাষ্ট্রধর্ম ইসলাম। সংবিধানের Article 2 তে আছে: [State Religion] Islam is the religion of the State. [আলজেরিয়ার মূল সংবিধান: http://goo.gl/3CEtdC অনুবাদ: http://goo.gl/Htio6a] ৬. ইন্দোনেশিয়ার রাষ্ট্রধর্ম ইসলাম। সংবিধানের Article 29 এ বলা হয়েছে Religion: (1) The State shall be based upon the belief in the One and Only God. (2) The State guarantees all persons the freedom of worship, each according to his/her own religion or belief. এক ও একমাত্র গডে বিশ্বাস ইসলাম ছাড়া অন্য কোনো ধর্মে নেই। [ইন্দোনেশিয়ার সংবিধান: http://goo.gl/QemKDm] এ ছাড়া আরো যেসব দেশে রাষ্ট্রধর্ম ইসলাম: Afghanistan, Algeria, Bahrain, Brunei, Egypt, Jordan, Kuwait, Libya, Maldives, Mauritania, Morocco, Oman, Pakistan, Qatar, Saudi, Arabia, Somalia, Somaliland, Tunisia, Turkey, United Arab Emirates, Yemen, Maldives, Pakistan, Saudi Arabia. [দেখুন: https://goo.gl/GWzkfE] অথচ কী সুন্দর গলাবাজি করে বারবার মালয়েশিয়া ও ইন্দোনেশিয়ার কথা বলা হচ্ছিল! দ্বিতীয় প্রশ্নে জানতে চাওয়া হয়, রাষ্ট্রধর্মে ইসলাম না থাকলে কি দেশে ইসলাম থাকবে না? আমাদের প্রশ্ন, রাষ্ট্রধর্মে ইসলাম থাকা- না থাকা যদি সমান হয়, তাহলে থাকতে এত সমস্যা কেন? তৃতীয় প্রশ্নের উত্তরে বলি, রাজনীতিটা মতলবেরই, মতলব ছাড়া কে কবে কথা বলে! বাকী মতলবটা জনগণের উপকারী হলো কিনা, প্রশ্ন সেটা। আমাদের পাল্টা প্রশ্ন, ৭২ -এর সংবিধানে কেন রাষ্ট্রধর্ম ইসলাম স্থান পায় নি? কেন সেখানে সেকুলারিজম জায়গা পেল? সেখানে কাদের মতলব ছিল? দেশের জনসংখ্যার কত পার্সেন্ট তখন সেকুলার ছিল? আমরা তো রোজা রেখে মুক্তিযুদ্ধ করার গল্প জেনেছি, নামাযে দোয়া করে যুদ্ধে বের হওয়ার দৃষ্টান্ত দেখেছি। তাহলে তাদের ত্যাগের এত অমর্যাদা কেন? == মাত্র ৫-৭ মিনিটের কথায় এত গলাবাজি আর মিথ্যার আশ্রয় নিলে কীভাবে হবে ভাই! সত্য দিয়ে মোকাবিলা করুন, যদি বুদ্ধিমান ও সাহসী হয়ে থাকেন! [মাওলানা Yousuf Sultan সাহেবের লেখা ]
#
# Status: sad
# Sentence: বয়কট করলাম একসময়ের প্রিয় ৭১ টিভি কে। ইসলাম বিরুদ্ধচারীতা করার কারনে। RIP ৭১টিভি
#
# Status: angry
# Sentence: বন্ধ করলাম ৭১ টিভি
#
# Status: happy
# Sentence: বহাল থাকছে রাষ্ট্রধর্ম ইসলাম। Alhamdulilha. 71 t vকতো কষ্ট হচ্ছে আজ
#
# Status: angry
# Sentence: আজকে তেকে নতুন issu খোজ সালা দালাল dv
#
# Status: angry
# Sentence: রাষ্ট্রধর্ম ইসলাম বাতিল দাবির পৃষ্ঠপোষক ৭১ টিভির লাইসেন্স বাতিল করা হোক
#
# Status: surprise
# Sentence: ইসলাম রক্ষায় শুধু ভারতীয় নয়, ইসরাইলের পন্য নয়, ইউরোপীয় পন্য নয় সবার আগে বর্জন করুন এই দেশীয় নাস্তিকদের ধোসর যমুনা গ্রপের সকল পন্য । কেননা এইদেশের নাস্তিকদের সবচেয়ে শক্তিশালী মিড়িয়া হলো ৭১ টিভি । . আর এই ৭১ টিভির মালিক হলো নাস্তিকদের শিরমনি মোজাম্মেল বাবু । যাঁর সিংহভাগ আয় হয় যমুনা গ্রুপের পন্য বিক্রির মাধ্যমে । যমুনা গ্রপের পন্যর মধ্যে উল্লেখযোগ্য হলো ফ্রেস ব্রান্ডের আটা, ময়দা, সুজি তাই আসুন যমুনা গ্রুপের সকল পন্য বর্জন করে ইসলামের জন্য নিজের মনকে সবার আগে ফ্রেশ করি ।
#
# Status: surprise
# Sentence: রাষ্ট্র ও রাষ্ট্রধর্ম রাষ্ট্রের মৌলিক উপাদান ৪টি। ১. জনসমষ্টি। ২. নির্দিষ্ট ভুখণ্ড। ৩. সরকার। ৪.সার্বভৌমত্ব। অর্থাৎ কোথাও এ চারটি জিনিসের সমন্বয় পাওয়া গেলেই তাকে রাষ্ট্র বলা হবে। এ চারটি উপাদানের মূল কেন্দ্রবিন্দু হলো প্রথমটি অর্থাৎ জনসমষ্টি। জনসমষ্টিকে ঘিরেই রাষ্টের অন্যসব আয়োজন। জনগণের প্রয়োজনেই রাষ্ট্র আইন প্রণয়ন করে। রাষ্ট্রের জনগণের সংস্কৃতিই রাষ্ট্রের সংস্কৃতি। রাষ্ট একটি সংগঠন। এর কোনো হাত-পা নেই। রাষ্ট্রের কোনো মুখ নেই। রাষ্ট্র কথা বলতে পারে না। এই যুক্তিতে রাষ্ট্রের কোনো ভাষার প্রয়োজন হওয়ার প্রশ্নই ওঠে না। কিন্তু রাষ্ট্রের সবচেয়ে বড় উপাদান জনসমষ্টি ভাষা ব্যবহার করে, তাদের ভাষা আছে বলেই রাষ্ট্রেরও ভাষা আছে। জনগণের ভাষাই রাষ্ট্রের ভাষা বা রাষ্ট্রভাষা। তেমনি রাষ্ট্র নামাজ পড়তে পারে না। রাখে না রোজা। করতে পারে না পূজা। রাষ্ট্র নিজে বড়দিনও পালন করতে পারে না। তাহলে রাষ্ট্রের ধর্ম থাকবে কেন? এর উত্তরও ঠিক আগেরটির মতোই। রাষ্ট্রের জনসমষ্টির ধর্ম আছে বলেই রাষ্ট্রেও ধর্ম থাকবে। অধিকাংশ নাগরিক যে ধর্মে বিশ্বাস করে। যে ধর্মকে লালন করে। সে ধর্মই তো রাষ্ট্রের ধর্ম। বর্তমান বাংলাদেশে ৩৯টি ভাষা প্রচলিত এবং সবকটি ভাষাই জীবিত। কিন্তু বাংলাদেশের সংবিধানে রাষ্ট্রভাষা চাকমা, সাঁওতালি, গারো, তিপ্পেরা, মণিপুরী না হয়ে বাংলা রাষ্ট্রভাষা হলো এতে অন্যভাষাগুলোর মর্যাদাহানী হয়েছে? সংবিধানের প্রথম ভাগের ৩-এ বলা হয়েছে ‘প্রজাতন্ত্রের রাষ্ট্রভাষা বাংলা’৷ এখানে অন্য কোনো ভাষার কথা উল্লেখ করা হয়নি। কিন্তু সংবিধানের প্রথম ভাগের যেখানে রাষ্ট্রধর্মের কথা আছে সেখানে বলা হয়েছে, ‘প্রজাতন্ত্রের রাষ্ট্রধর্ম ইসলাম, তবে হিন্দু, বৌদ্ধ, খ্রীষ্টানসহ অন্যান্য ধর্ম পালনে রাষ্ট্র সমমর্যাদা ও সমঅধিকার নিশ্চিত করিবেন’। ভাষার ব্যাপারে অন্য ভাষাভাষীদের সমমর্যাদার কথা উল্লেখ করা হয়নি অথচ ধর্মের ক্ষেত্রে অন্যসব ধর্মাবলম্বীদের সমমর্যাদার কথা উল্লেখ করে দেয়া হয়েছে। এতেও কি তাদের অধিকার নিশ্চিত হয়নি? নাকি ৯০% মুসলমানের ধর্মের প্রতিই তাদের মূল বিদ্বেষ? ০৯% হিন্দুদের ধর্মকে রাষ্ট্রধর্ম করতে পারলেই তাদের আত্মা খুশি হবে?যদি রাষ্ট্রধর্ম হিন্দু হতো তাহলে কি আজকের ওইসব বুদ্ধিজীবি(!)রা কোনো প্রশ্ন করতেন? রাষ্ট্রধর্ম ইসলাম থাকলে সমস্যাটা কি? ইসলামই কি একমাত্র উন্নয়নের অন্তরায়? রাষ্ট্রধর্ম থেকে ইসলামকে বাদ দিলেই কি বাংলাদেশের ক্রমবর্ধমান খুন, ধর্ষণ, ব্যাংক ক্যালেঙ্কারী, ছিনতাই বন্ধ হয়ে যাবে? রাষ্ট্রধর্ম ইসলাম থাকলে অন্য ধর্মাবলম্বীদের কি কোনো সমস্যা হচ্ছে? না। সমস্যাটা অন্য জায়গায়। রাষ্ট্রধর্ম কোনো উন্নয়নের অন্তরায় নয় বরং হিজাব, আজান, কোরবানি নিষিদ্ধ করার পথে একটি বড় বাধা। এই বাধাটি দূর করা গেলেই কামাল পাশার মতো হিজাব, আজান, প্রকাশ্যে জামাতে নামাজ বন্ধ করা যাবে। আদালতকে মনে রাখতে হবে, রাষ্ট্রভাষার জন্য যে জাতি প্রাণ দিয়ে বিশ্বে নজির স্থাপন করতে পারে সে জাতি রাষ্ট্রধর্ম রক্ষার জন্যও প্রাণ দিতে সদা প্রস্তুত। রাষ্ট্রভাষার জন্য ৫ জন প্রাণ দিতে পারলে ৫ লাখ সালাম, বরকত, রফিক, জব্বার শফিউররা প্রস্তুত আছে।
#
# Status: angry
# Sentence: ৭১ টিভি হলো টিভি নামের কলঙ্ক। ৭১ এর মালিক একটি জারজা সন্তান।ইসলাম বিরোধী মিডিয়া ধ্বংস হোক।♦BOYCOTT 71TV♦
#
# Status: angry
# Sentence: হলুদ সাংবাদিকতা করে যারা তাদের এভাবে স্বাধীনতা ও মহান মুক্তিযুদ্ধ নিয়ে কোনো কথা বলা মানায় না। মুক্তিযুদ্ধকে নিয়ে ভন্ডামি করা ছাড়ুন।
#
# Status: happy
# Sentence: বাংলাদেশ ক্রিকেট জগৎ বাংলাদেশের ক্রিকেটর গৌরব, ক্রিকেটের ইতিহাস, বাংলাদেশের ক্রিকেটের লাইভ ভিডিও সহকারে আপডেট পেতে লাইক দিন পেজে। আপনার একটা লাইক আমাদেরকে উৎসাহ দিবে দেশের ক্রিকেটকে নিয়ে কাজ করার। বাংলাদেশ ক্রিকেট জগৎ T20 ওয়াল্ড কাপের সব ম্যাচ ভিডিও সহকারে আপডেট পেতে লাইক দিন পেজে। কারো কোন sports এর ভিডিওর দরকার হলে সাথে সাথে আমাদের কে জানাবেন। আমরা দিয়ে দিবো পেজে। বাংলাদেশ ক্রিকেট জগৎ বাংলাদেশ ক্রিকেট জগৎ বাংলাদেশ ক্রিকেট জগৎ বাংলাদেশ ক্রিকেট জগৎ
#
# Status: angry
# Sentence: রাষ্ট্রধর্ম ইসলাম বাতিল দাবির পৃষ্ঠপোষক ৭১ টিভির লাইসেন্স বাতিল করা হোক।
#
# Status: sad
# Sentence: ৭১ করে লাবকি এহন ছলে৭২। দেশ কত সুংখে আছে
#
# Status: surprise
# Sentence: ১৯৪৭ সালে কি ঘটেছিল?৪৭ না হলে কি আজকের বাংলাদেশ পেতাম?
#
# Status: fear
# Sentence: আজ যদি তনুর বিচার না হয় কাল তোর বোনের ধর্ষিতার বিচার হবে না। মনে রাখোস
#
# Status: sad
# Sentence: কি পেয়েছি আমরা শাদিন দেশে চুর বাটপার
#
# Status: sad
# Sentence: ৭১ টিভি ও ফ্রেশ ব্র্যান্ডের সকল পন্য বর্জন করুন, ফ্রেশ থাকুন.... বাংলাদেশের প্রধান ইসলাম বিদ্বেষী মিডিয়া হলো একাত্তর টিভি। আওয়ামীপন্থী সাংবাদিক মোজাম্মেল বাবু ৭১ টিভি শুরু করার পর ২০১৩ সালে মেঘনা গ্রুপের কাছে ৫১% শেয়ার বিক্রি করে দেয়। শুরুর দিক থেকেই ৭১ টিভি প্রচন্ড ইসলাম বিদ্বেষী ভুমিকা পালন করে আসছে। উত্সাহ দেয় নাস্তিকদের বিভিন্ন কর্মকান্ডের। গত কয়েকদিন ধরে রাষ্ট্রধর্ম ইসলাম নিয়ে ৭১ টিভি কিছু টকশো আয়োজন করে। সেই টকশোগুলোতে প্রত্যক্ষ্যভাবে ইসলাম যেন রাষ্ট্রধর্ম না থাকে সেই জন্য বিভিন্ন ধর্মহীন লোকদেরকে টকশোতে এনে ইসলাম বিদ্বেষী মনোভাব প্রচন্ডভাবে প্রকাশ করতে থাকে। ৭১ টিভি সব সময়ই আলেম ওলামাদের হেয় করার চেষ্টায় থাকে। এইভাবে প্রতিনিয়তই মেঘনা গ্রুপের মালিকানাধীন ৭১ টিভি ইসলামের বিরুদ্ধে অবস্থান নিয়ে আসছে। একজন মুসলিম হিসেবে আপনার আমার ঈমানী দ্বায়িত্ব হলো ৭১ টিভি সহ এদের পণ্য বর্জন করা। মেঘনা গ্রুপের উল্লেখযোগ্য ব্র্যান্ড হলো ফ্রেশ। ফ্রেশ ব্র্যান্ডের কোনো পণ্য কিনে মূলত আপনি ৭১ টিভিকেই টাকা দিচ্ছেন। চিন্তা করুন আপনার টাকায় ৭১ টিভি ইসলাম বিদ্বেষী ভুমিকা পালন করছে। আসুন নিজে ও ইসলামকে ফ্রেশ রাখতে ফ্রেশ ব্যান্ড বর্জন করি।
#
# Status: sad
# Sentence: সোয়াবের কাজ বিনা হিসাবে জাহান্নাম।
#
# Status: sad
# Sentence: তনুই একমাত্র তনু নয়, আরও তনু আছে। ২৬শে মার্চ ৪৫তম মহান স্বাধীনতা দিবসে প্রধানমন্ত্রী শেখ হাসিনার প্রতিঃ ক্ষোভে উত্তাল কুমিল্লা! অবিলম্বে কুমিল্লা বিভাগটি গঠন করুন =========================================== কুমিল্লা ভিক্টোরিয়া সরকারি কলেজের ইতিহাস বিভাগের স্নাতক (সম্মান) দ্বিতীয় বর্ষের ছাত্রী ও নাট্যকর্মী সোহাগী জাহান তনুকে ধর্ষণ শেষে হত্যা করা হয়। কালভার্টের পাশের জঙ্গলে মাথা থেত্লানো সোহাগীর অর্ধনগ্ন মৃতদেহ উদ্ধার করা হয়। ঘটনায় জড়িতদের অবিলম্বে গ্রেফতার ও তাদের বিচার দাবিতে ক্ষোভে উত্তাল হয়ে উঠেছে কুমিল্লা নগরী। এদিকে তনুর বাড়িতে চলছে তার বাবা-মা ও স্বজনদের আহাজারি। কুমিল্লা ভিক্টোরিয়া কলেজ, সরকারি মহিলা কলেজসহ নগরীর বিভিন্ন শিক্ষা প্রতিষ্ঠানের দল নিবিশেষে হাজার হাজার শিক্ষার্থীসহ বিভিন্ন সামাজিক ও সাংস্কৃতিক সংগঠনের নেতা-কর্মীরা মাঠে নেমেছে। শিক্ষার্থীসহ প্রতিবাদী জনতা নগরীতে দফায় দফায় বিক্ষোভ মিছিল শেষে দুপুরে কান্দিরপাড় পূবালী চত্ত্বরে এসে মানববন্ধন ও সমাবেশ করে। রাজধানী ঢাকাসহ দেশের বিভিন্ন স্থানে এ নিয়ে গত চার দিনে বিক্ষোভ ও প্রতিবাদ সমাবেশ করা হচ্ছে। ফেসবুকেও বইছে প্রতিবাদের ঝড়। ৬৪টি জেলা গঠনের পরে প্রস্তাবমত বাংলাদেশকে ৯টি বিভাগে বিভক্ত না করায় রাষ্ট্র-অবকাঠামো শিথীল-সন্ত্রাসমুখী হয়। এতে সন্ত্রাসবাদী-অনৈতিক চেতনা ক্রমবর্ধমান হয়। খালেদা জিয়া অর্ধশিক্ষিত ও কমবুঝ প্রধানমন্ত্রী। তিনি না হয় বরিশাল ও সিলেট বিভাগ গঠন করে বাকী তিনটি বিভাগ গঠন করলেন না। আর বার বার বলা সত্তেও শিক্ষিত ও বুঝ প্রধানমন্ত্রী শেখ হাসিনা ১৯৯৭-এ ইউনিয়নকে ৯টি ওয়ার্ডে বিভক্তির সাথে সাথে বাংলাদেশকে ৯টি বিভাগে বিভক্ত করলেন না। বার বার বলায় পাঁচ বছর পরে ময়মনসিংহ বিভাগ করলেন। বিগত সাতবছরের প্রধানমন্ত্রী শেখ হাসিনার সরকারামলে প্রবৃদ্ধির গড় হার প্রায় ৬.২% ছিল। আগামী বছর প্রবৃদ্ধির হার ৭.০% উপরে হবে। আগামী বছর প্রধানমন্ত্রী শেখ হাসিনা বার বার শুনাবেন, আমি প্রবৃদ্ধির গড় হার ৭.০% তুলেছি যা জাতির ইতিহাস। এইসাথে কুমিল্লা বিভাগটিও হলে প্রবৃদ্ধির গড় হার ক্রমশঃ ৭.৮%-এর উপরে হতো। প্রধানমন্ত্রী শেখ হাসিনাও বার বার এ কথা শুনাতে পারতেন না? কুমিল্লা বিভাগটি এখনও বাকী আছে। বাংলাদেশকে ৮টি বিভাগে বিভক্তির পরে এখন আর একটি বিভাগের জন্যে কোন প্রভাবশীল আন্দোলন হবে না। অথচ কুমিল্লা বিভাগ গঠনের জন্যে বার্ষিক ব্যয় বাড়বে মাত্র চারকেটি টাকা। বাংলাদেশকে ৯টি বিভাগে বিভক্ত করা হলেই রাষ্ট্র-অবকাঠামো সুষম-গণতন্ত্রমুখী হবে।সকলক্ষেত্রে উদার, নৈতিক ও সৃজনশীল চেতনা বিকাশের ধারা দেবে। প্রবৃদ্ধি গড়হার ১.০% বৃদ্ধিসহ জাতির নিরাপত্তা ও উন্নয়ণের ধারা বাড়বে। এখন জরুরী ভিত্তিতে বাকী কুমিল্লা বিভাগটি করুন।
#
# Status: angry
# Sentence: নাস্তিকদের দালাল একাওর টিভি বন্ধ করা হোক,https://www.facebook.com/events/510113745860941
#
# Status: angry
# Sentence: #Ban_EkattorTvবাংলাদেশের রাষ্ট্রধর্ম ইসলাম ছিল আছে থাকবেঃ www.facebook.com/IslamisTheStateReligion
#
# Status: surprise
# Sentence: ধর্ষনে জন্য ধর্ষককে প্রকার্শে জনগনের সামনে ফাসির আইন সংবিধানের আওতায় আনা হোক তাহলেই ধর্ষকে ধর্ষন কমবে।আমি ১০০% একমত আর আপনি ?
#
# Status: sad
# Sentence: রাষ্ট্র যেখানে ধর্ষন কারিকে বাছাতেসচেষ্ট সেখানে ধর্ষন হবেনাত কি হবে তনু কে কেবা কারা ধর্ষন করেছে এটা সবাই জানে কিন্তু কেন আরাল করা হচ্ছে তাদের কে
#
# Status: surprise
# Sentence: আসল রাস্তা বাদ দিয়ে গাঁধার দল ধর্ষন বন্ধ করতে চায়,ইসলাম ছাড়া বিকল্প নাই
#
# Status: angry
# Sentence: কয় স্টিক মারছেন?
#
# Status: surprise
# Sentence: ভাই কিছু মেয়েরা আবার ধর্ষনের নাটক করে, টাকা আদায় করে। তনুর কথা বলছি না।
#
# Status: surprise
# Sentence: যা হোক অনেকে অনেক আইটেম লিখেচেন তবে এটা হয় কার দারায় আমরা পুরষের কারনে তাই না। এখন বাল সাজতে চান আরে আপনে বাল ত দুনিয়া বাল।
#
# Status: angry
# Sentence: ইভটিজিং কারীদের ক্রস ফায়ারের আওতায় আনা উচিত বলে আমি মনে করি।তাহলে অপরাধ কমবে।
#
# Status: happy
# Sentence: ধর্ষনের শাশতি মিতু র্দ্নড হলে আর মহিলারা ১০০%হেজাব মানি ফরদা করা নিস্ছিত করতে হবে তাহলে আপনারা নিজেই রেজাল দেখতে পাবেন ৷
#
# Status: sad
# Sentence: ৭১ টিভিতে গলাবাজি ও তথ্য বিকৃতির বিরুদ্ধে মাওলানা সাখাওয়াত হোস... ৭১ টিভিতে গলাবাজি ও তথ্য বিকৃতির বিরুদ্ধে মাওলানা সাখাওয়াত হোসেন একা ভালই জবাব দিয়েছে। প্রসঙ্গ রাষ্ট্রধর্ম ইসলাম নিয়ে একাত্তর জার্নালের গলাবাজি ও তথ্য বিকৃতি: গতকাল একাত্তর জার্নালে মুফতী সাখাওয়াত হুসাইনকে রাষ্ট্রধর্ম ইসলাম নিয়ে বিভিন্ন প্রশ্ন করা হয়। তাঁর উত্তর শোনার আগেই বারবার থামিয়ে ভিন্ন প্রসঙ্গ ও ভুল তথ্য ছুঁড়ে বিভ্রান্ত করার চেষ্টা করা হয়। অনুষ্ঠানে যে তিনটি মৌলিক প্রশ্ন করা হয় তা হলো: ১. পৃথিবীর কয়টা মুসলিম দেশে সংবিধানে ইসলাম আছে? কোন দেশে? ২. রাষ্ট্রধর্মে ইসলাম না থাকলে কি দেশে ইসলাম থাকবে না? ৩. এরশাদ একটা মতলব নিয়ে এটা করেছিল, পরবর্তীতে বিএনপি ভয়ে তা বাদ দেয় নি। [ভিডিও লিংক: https://youtu.be/ZzeP7HQCqv8] প্রথম প্রশ্নের উত্তরে মুফতী সাহেব মধ্যপ্রাচ্যের মুসলিম দেশসহ বিশ্বের অনেকগুলো মুসলিম দেশে সংবিধানে রাষ্ট্রধর্ম ইসলাম থাকার কথা বললে উপস্থাপিকা জোর দিয়ে বলার চেষ্টা করেন যে, ইন্দোনেশিয়া, মালয়েশিয়াতে তো নেই। আরো বলেন, ইরাক, ইরানেও নেই। মুফতী সাহেব মরক্কো, আলজেরিয়ার কথা বললে, সেগুলোও উপস্থাপিকা অস্বীকার করেন। অথচ আমরা দেখি: ১. মালয়েশিয়ার রাষ্ট্রধর্ম ইসলাম। ফেডেরাল কন্সটিটিউশনের প্রথম ভাগের ৩ এর ১ অনুচ্ছেদে বলা হয়েছে: Islam is the religion of the Federation; but other religions may be practised in peace and harmony in any part of the Federation. [দেখুন: মালয়েশিয়ার সংবিধান: http://goo.gl/svUNdA] ২. ইরাকের রাষ্ট্রধর্ম ইসলাম। সংবিধানের 2-2A তে আছে: Islam is the official religion of the State and is a foundation source of legislation: A. No law may be enacted that contradicts the established provisions of Islam. [ইরাকের সংবিধান: http://goo.gl/EY5wvY] ৩. ইরানের রাষ্ট্রধর্ম ইসলাম (শী'য়া মতবাদ)। সংবিধানের Article 12 -এ আছে: The official religion of Iran is Islam. [ইরানের মূল সংবিধান: http://goo.gl/Tp0T3Z; আন-অফিশিয়াল অনুবাদ: http://goo.gl/fzB1j6 ] ৪. মরক্কোর রাষ্ট্রধর্ম ইসলাম। সংবিধানে Article 6 -এ আছে: Article 6: Islam shall be the state religion. The state shall guarantee freedom of worship for all. [মরক্কোর সংবিধান: http://goo.gl/3y08p7] ৫. আলজেরিয়ার রাষ্ট্রধর্ম ইসলাম। সংবিধানের Article 2 তে আছে: [State Religion] Islam is the religion of the State. [আলজেরিয়ার মূল সংবিধান: http://goo.gl/3CEtdC অনুবাদ: http://goo.gl/Htio6a] ৬. ইন্দোনেশিয়ার রাষ্ট্রধর্ম ইসলাম। সংবিধানের Article 29 এ বলা হয়েছে Religion: (1) The State shall be based upon the belief in the One and Only God. (2) The State guarantees all persons the freedom of worship, each according to his/her own religion or belief. এক ও একমাত্র গডে বিশ্বাস ইসলাম ছাড়া অন্য কোনো ধর্মে নেই। [ইন্দোনেশিয়ার সংবিধান: http://goo.gl/QemKDm] এ ছাড়া আরো যেসব দেশে রাষ্ট্রধর্ম ইসলাম: Afghanistan, Algeria, Bahrain, Brunei, Egypt, Jordan, Kuwait, Libya, Maldives, Mauritania, Morocco, Oman, Pakistan, Qatar, Saudi, Arabia, Somalia, Somaliland, Tunisia, Turkey, United Arab Emirates, Yemen, Maldives, Pakistan, Saudi Arabia. [দেখুন: https://goo.gl/GWzkfE] অথচ কী সুন্দর গলাবাজি করে বারবার মালয়েশিয়া ও ইন্দোনেশিয়ার কথা বলা হচ্ছিল! দ্বিতীয় প্রশ্নে জানতে চাওয়া হয়, রাষ্ট্রধর্মে ইসলাম না থাকলে কি দেশে ইসলাম থাকবে না? আমাদের প্রশ্ন, রাষ্ট্রধর্মে ইসলাম থাকা- না থাকা যদি সমান হয়, তাহলে থাকতে এত সমস্যা কেন? তৃতীয় প্রশ্নের উত্তরে বলি, রাজনীতিটা মতলবেরই, মতলব ছাড়া কে কবে কথা বলে! বাকী মতলবটা জনগণের উপকারী হলো কিনা, প্রশ্ন সেটা। আমাদের পাল্টা প্রশ্ন, ৭২ -এর সংবিধানে কেন রাষ্ট্রধর্ম ইসলাম স্থান পায় নি? কেন সেখানে সেকুলারিজম জায়গা পেল? সেখানে কাদের মতলব ছিল? দেশের জনসংখ্যার কত পার্সেন্ট তখন সেকুলার ছিল? আমরা তো রোজা রেখে মুক্তিযুদ্ধ করার গল্প জেনেছি, নামাযে দোয়া করে যুদ্ধে বের হওয়ার দৃষ্টান্ত দেখেছি। তাহলে তাদের ত্যাগের এত অমর্যাদা কেন? == মাত্র ৫-৭ মিনিটের কথায় এত গলাবাজি আর মিথ্যার আশ্রয় নিলে কীভাবে হবে ভাই! সত্য দিয়ে মোকাবিলা করুন, যদি বুদ্ধিমান ও সাহসী হয়ে থাকেন! [মাওলানা Yousuf Sultan সাহেবের লেখা ]
#
# Status: sad
# Sentence: এর জন্যে দায়ী মোবাইল ফন কম্পানীগুলা। অল্প বয়সী মেয়েদের হাতে মোবাইল দেয়া ঠিক নয় @!
#
# Status: sad
# Sentence: মানুষের ভিতর থেকে যখন ধর্মের ব্যবহার চলে যায় তখন এসব হয়,
#
# Status: sad
# Sentence: মিডিয়া জানে না, বা ডামা চাপা দেয়া হয়তো অারো অনেক ঘঠনা অাছে।।অামরা জানি না
#
# Status: disgust
# Sentence: এই সরকার থাকলে ধরষন বারভে কমবে না.........
#
# Status: sad
# Sentence: ও,দের,ফাঁসি,চাই,সরকার,বিচার,করো,দয়া,করে
#
# Status: surprise
# Sentence: হবেই তো তোরাতো রাষ্ট ধরম ইসলামের বিপক্ষে কাজ করস।ভারতের মতো ধর্ষণের দেশে পরিণত হচ্ছে।
#
# Status: angry
# Sentence: নাসতিক দালাল মিডিয়া তোমরা
#
# Status: surprise
# Sentence: দেশ আছে না কী ?
#
# Status: surprise
# Sentence: শেখ হাসিনা তো বলছে কুমিল্লার মানুষ ভাল হলে বিভাগ করবেন। আপনারা আগে ভাল হন। জয় বাংলা।
#
# Status: surprise
# Sentence: তনুই একমাত্র তনু নয়, আরও তনু আছে। ২৬শে মার্চ ৪৫তম মহান স্বাধীনতা দিবসে প্রধানমন্ত্রী শেখ হাসিনার প্রতিঃ ক্ষোভে উত্তাল কুমিল্লা! অবিলম্বে কুমিল্লা বিভাগটি গঠন করুন =========================================== কুমিল্লা ভিক্টোরিয়া সরকারি কলেজের ইতিহাস বিভাগের স্নাতক (সম্মান) দ্বিতীয় বর্ষের ছাত্রী ও নাট্যকর্মী সোহাগী জাহান তনুকে ধর্ষণ শেষে হত্যা করা হয়। কালভার্টের পাশের জঙ্গলে মাথা থেত্লানো সোহাগীর অর্ধনগ্ন মৃতদেহ উদ্ধার করা হয়। ঘটনায় জড়িতদের অবিলম্বে গ্রেফতার ও তাদের বিচার দাবিতে ক্ষোভে উত্তাল হয়ে উঠেছে কুমিল্লা নগরী। এদিকে তনুর বাড়িতে চলছে তার বাবা-মা ও স্বজনদের আহাজারি। কুমিল্লা ভিক্টোরিয়া কলেজ, সরকারি মহিলা কলেজসহ নগরীর বিভিন্ন শিক্ষা প্রতিষ্ঠানের দল নিবিশেষে হাজার হাজার শিক্ষার্থীসহ বিভিন্ন সামাজিক ও সাংস্কৃতিক সংগঠনের নেতা-কর্মীরা মাঠে নেমেছে। শিক্ষার্থীসহ প্রতিবাদী জনতা নগরীতে দফায় দফায় বিক্ষোভ মিছিল শেষে দুপুরে কান্দিরপাড় পূবালী চত্ত্বরে এসে মানববন্ধন ও সমাবেশ করে। রাজধানী ঢাকাসহ দেশের বিভিন্ন স্থানে এ নিয়ে গত চার দিনে বিক্ষোভ ও প্রতিবাদ সমাবেশ করা হচ্ছে। ফেসবুকেও বইছে প্রতিবাদের ঝড়। ৬৪টি জেলা গঠনের পরে প্রস্তাবমত বাংলাদেশকে ৯টি বিভাগে বিভক্ত না করায় রাষ্ট্র-অবকাঠামো শিথীল-সন্ত্রাসমুখী হয়। এতে সন্ত্রাসবাদী-অনৈতিক চেতনা ক্রমবর্ধমান হয়। খালেদা জিয়া অর্ধশিক্ষিত ও কমবুঝ প্রধানমন্ত্রী। তিনি না হয় বরিশাল ও সিলেট বিভাগ গঠন করে বাকী তিনটি বিভাগ গঠন করলেন না। আর বার বার বলা সত্তেও শিক্ষিত ও বুঝ প্রধানমন্ত্রী শেখ হাসিনা ১৯৯৭-এ ইউনিয়নকে ৯টি ওয়ার্ডে বিভক্তির সাথে সাথে বাংলাদেশকে ৯টি বিভাগে বিভক্ত করলেন না। বার বার বলায় পাঁচ বছর পরে ময়মনসিংহ বিভাগ করলেন। বিগত সাতবছরের প্রধানমন্ত্রী শেখ হাসিনার সরকারামলে প্রবৃদ্ধির গড় হার প্রায় ৬.২% ছিল। আগামী বছর প্রবৃদ্ধির হার ৭.০% উপরে হবে। আগামী বছর প্রধানমন্ত্রী শেখ হাসিনা বার বার শুনাবেন, আমি প্রবৃদ্ধির গড় হার ৭.০% তুলেছি যা জাতির ইতিহাস। এইসাথে কুমিল্লা বিভাগটিও হলে প্রবৃদ্ধির গড় হার ক্রমশঃ ৭.৮%-এর উপরে হতো। প্রধানমন্ত্রী শেখ হাসিনাও বার বার এ কথা শুনাতে পারতেন না? কুমিল্লা বিভাগটি এখনও বাকী আছে। বাংলাদেশকে ৮টি বিভাগে বিভক্তির পরে এখন আর একটি বিভাগের জন্যে কোন প্রভাবশীল আন্দোলন হবে না। অথচ কুমিল্লা বিভাগ গঠনের জন্যে বার্ষিক ব্যয় বাড়বে মাত্র চারকেটি টাকা। বাংলাদেশকে ৯টি বিভাগে বিভক্ত করা হলেই রাষ্ট্র-অবকাঠামো সুষম-গণতন্ত্রমুখী হবে।সকলক্ষেত্রে উদার, নৈতিক ও সৃজনশীল চেতনা বিকাশের ধারা দেবে। প্রবৃদ্ধি গড়হার ১.০% বৃদ্ধিসহ জাতির নিরাপত্তা ও উন্নয়ণের ধারা বাড়বে। এখন জরুরী ভিত্তিতে বাকী কুমিল্লা বিভাগটি করুন।
#
# Status: angry
# Sentence: বয়কট করলাম ইসলাম বিরুদ্ধচারী ৭১ টিভি
#
# Status: sad
# ...
#
# Status: sad
# Sentence: ছবিটা টিবি চ্যানেল খবর মাদ্যমে প্রকাশ করুন প্লিজ B TV,মাছরাঙা,অথবা যে কোনো চ্যানেলএ।
#
# Status: sad
# Sentence: মেহেদি তার বাবা,মা কে খুঁজে পাবেই ! কারন আপনার ফেজবুক পেজে যেহেতু খবরটি দেওয়া হয়েছে ! মেহেদি ওর বাবা ,মায়ের দেখা পেলে সেটাও জানাবেন আশা রাখি !
#
# Status: sad
# Sentence: দয়া করে বাংলা চ্যালেনগুলোতে খবরের মাধ্যমে বাচ্চাটির ছবি দিয়ে প্রকাশ করুন। প্লিজ।
#
# Status: angry
# Sentence: পুলিশ ভাইকে অনেক অনেক ধননবাদ এই ভালো কাছটি করার জনন কিনত আমার একটা উনরোদ ওর মা কে একটা উচিদ শিকখা দিবেন ওর মা জেন আর কোনো দিন পহেলা বইশাকে না আশে
#
# Status: happy
# Sentence: মানবিক কাজে সহযোগীতা করে উদারমনার পরিচয় দেওয়ার জন্য ইমরান এইচ সরকারকে ধন্যবাদ। ছেলেটা তার ফ্যামেলীকে ফিরে পাক, কামনা করছি।
#
# Status: happy
# Sentence: Dr. Imran vaiya ছেলে টাকে বাবা মার কাছে পিরিয়ে দিয়েছেন কারন আমি ওমানে আছি। ছেলেটার বাবা মা যদি পিরিয়ে পা তাহলে খুশি হব।
#
# Status: happy
# Sentence: খবরটি আপনারা যারা পেয়ে থাকেন তাদের কাছে অনুরুদ রইল আপনারা সবাই শেয়ার করে অন্যদেরকে জানান**
#
# Status: sad
# Sentence: মেহেদী যেন তারাতারি ওর বাবা মাকে খুজে পায় এই কামনা করি।আাললাহ মহান তিনি সব কিছুই পারেন।
#
# Status: happy
# Sentence: আমি মোস্তাক ভাই কে চিনি। তার দক্ষতা ও কাজে কোন প্রতিদ্বন্দ্বী নেই। ইনশাল্লাহ তিনি ওর অভিভাবক কে ঠিকি খুজে বের করবেন।
#
# Status: happy
# Sentence: ধন্যবাদ। ড: ইমরান ভাইয়াকে, বন্দুরা তোমারা এই পোস্টি বেশী করে শেয়ার কর, আর বেবির দোয়া করবে,যাতে ও ওর বাবা মাকে খুব তারাতারি খুজে পায়।
#
# Status: happy
# Sentence: এই যে ভাই,এই যে আপু, মুসলমান হিসাবে উক্ত পেইজটি ☞ ☞ ইতিহাসের স্বাক্ষী ☞ ☞ ইতিহাসের স্বাক্ষী পরিদর্শন /পর্যালোচনা করার পর যদি আপনার বিবেক স্বাক্ষ দেয়,তাহলে আপনার মুল্যবান সহযোগিতা প্রধান করে, দেশ ও মুসলিম জাতিসত্তার পক্ষে লেখালেখি করার ও প্রচারপ্রসার করার সুযোগ করে দিন"
#
# Status: happy
# Sentence: ইমরান এইচ সরকার আজকাল দেশের ব্যপারেও ভাবতে শুরু করেছে বলে মনে হয়। ভালো ভালো। অনেক অবস্র মনে হচ্ছে।
#
# Status: happy
# Sentence: আপনার অনেক কাজের মধ্যে এইটা একটা মহৎ কাজ
#
# Status: happy
# Sentence: উনি ভালো কাজ করছে একটা কেনো আপনারা ফালতু কমেন্টস করছেন, আসুন হেল্প করি বাচ্চাটাকে তার মা বাবার কাছে ফিরে যেতে।
#
# Status: angry
# Sentence: কি জন্য খুন করেছে
#
# Status: disgust
# Sentence: ছাগল!
#
# Status: angry
# Sentence: ইমরান নাস্তিক একটা ভালো কাজ করলা গতকাল যে ঝিনাইদহে দুজনকে পুলিশ খুন করছে সে খবর কি পাইছো
#
# Status: angry
# Sentence: তোর মত ছাগলরা তো তাবলবে
#
# Status: disgust
# Sentence: ভালো করে খোঁজ করে দেখেন এইটাও একটা বাটপারি পরিচয় হবার
#
# Status: sad
# Sentence: Fakhrul Islam ভাই মুখের বাসা এমন কেন
#
# Status: happy
# Sentence: বহুদিন পর একটা ভালো কাজ করলো পুলিশ লীগ
#
# Status: disgust
# Sentence: এসব Irresponsible বাপ মায়ের হাতে বাচ্চা আর তুলে দেয়াই উচিৎ না।
#
# Status: sad
# Sentence: শেয়ার দিলাম।আশা করছি শিশুটি এখন যেখানে আছে তার বাবা-মা'র কাছে পৌছার আগ পর্যন্ত ভালো থাকবে।
#
# Status: angry
# Sentence: সি সি কেমরায় দেখা হোক কার সাথে আসছে
#
# Status: sad
# Sentence: TV. Channel এ ছবি সহ ব্রেকিং নিউয দিলে ভালো হয়।
#
# Status: disgust
# Sentence: কিছু ছাগল শুভেচ্ছা দেওয়ার জায়গা পায়না।
#
# Status: happy
# Sentence: স্যার। আপনাকে ধন্যবাত আপার। মহা মৃলোবান পু্রট টা আমি সের করলাম
#
# Status: sad
# Sentence: বিকাল 3/4 টাই আমি হাতিরঝিল ছিলাম এই ছেলে টার থেকে 3/4 বছরের বর হবে ।একটা মেয়ে কাঁদতে কাঁদতে পুলিশ কে বলছিল সে তার ভাইকে হারিয়ে ফেলেছে।হাতিরঝিল কালি মনদীরের পাশে হাতিরঝিল বিজের কোনে যে পুলিশ গুলি ডিউটি করছিল তাদের মধ্যে এক পুলিশ সদস্য কাছে হয়তোবা এই হারানো ছেলে টার বাবার ফোন নাম্বার আছে।যদি এই হারানো ছেলে টা।ওই মেয়ে টার ভাই হই।
#
# Status: happy
# Sentence: নতুন বছর নতুন দিন শুভেচ্ছা ও সালাম নিন ভাল থাকুন সুস্থ থাকুন সারা বছর সঙ্গে থাকুন।
#
# Status: happy
# Sentence: ধন্যবাদ পুলিশ ভাই কে |
#
# Status: angry
# Sentence: ধন্যবাদ দেওয়ার কি আছে এটুকু কাজ যদি না পরে তাহলে কোন কজটা ...
#
# Status: happy
# Sentence: আল্লাহ্পাক
#
# Status: sad
# Sentence: রবীন্দ্রনাথ এত সিম্পল নারে ভাই
#
# Status: sad
# Sentence: অগোছালো স্বপ্ন আমিনতো মুসলিম রয়েছেএর জন্য তাকে ধন্যবাদ ।তবে বাবহারে বংশের পরিচয়।আমি পয়লা বৈশাখ পালন কোরব বাসসোরিক দিন হিসেবে ।তাই বলে আমি মুসলমান হিসাবে হিন্দু সাংইসকিতক মংগোল সুবাযাএ করা আর পুজা করা সমান ।তাই মুসলমান হিসেবে বৈশাখী পালন করতে সবাই কে নিসেধ করবো।
#
# Status: sad
# Sentence: ডিজিটাল পহেলা বৈশাখ "এসো হে বৈশাখ এসো......" দিয়ে শুরু হলো বর্ষবরণ। ইস! কী গান,হৃদয় শুয়ে যায় ৷ কিন্তু আপনী শিরক করেছেন ৷ কারন এই গানের একটি কলি হল #( "অগ্নিস্মানে সুচি হোক ধরা" অর্থাৎ আগুনে গোসল দিয়ে গোটা জগত পবিত্র হোক) ৷ হা হা হা হা হা হা হা হা হা হা আগুনের মাধ্যমে পবিএ হওয়া যায় ,এটা আসলে জানা ছিল না ৷ সবচেয়ে ভয়ঙ্কর শিরক হয় মঙল শোভাযাত্রায়। এই শোভাযাত্রায় অংশগ্রহণ করে সকল অমঙ্গল দূর করবে। মঙ্গল অমঙ্গলের মালিক কে ???????
#
# Status: sad
# Sentence: DC SIR.ফোন ধরে ,না এখন কি খবর বাচ্চার বাবা ,মা কে পাওয়া গেলো?
#
# Status: sad
# Sentence: এই শিশুটিকে তার পরিবার ফিরে পেতে সবাই শেয়ার করুন।
#
# Status: sad
# Sentence: বন্ধুরা।বাচ্চাটার সর্বশেষ অবস্হা জানান।
#
# Status: fear
# Sentence: যতদুর পারে আপনার শক্রি দিয়ে ওর বাবার কাছে পৌছিয়ে দিবেন স্যার।
#
# Status: sad
# Sentence: আল্লাহ্‌ ওর মা বাবার হাতে পিরিয়ে দাও
#
# Status: sad
# Sentence: ভাই ওর বাবা মা কে পাওয়া গেছে কি বলবেন ।।।।
#
# Status: angry
# Sentence: ডি সি পোষাক কোন টা??
#
# Status: happy
# Sentence: আলহামদুলিল্লাহ্‌ মেহেদী এখন তার পরিবারে আছে।
#
# Status: sad
# Sentence: সনতান জেনো তার মাকে ফিরে পায় সকলে দুয়া করুন
#
# Status: happy
# Sentence: জ্বি ভাই...:p
#
# Status: sad
# Sentence: রাজনৈতিক প্রচারের জন্য এই ছবি ব্যবহারিক হয়েছে।
#
# Status: fear
# Sentence: বাচ্ছা টিকে তার মা বাবার কাছে ফিরিয়ে দিলে অবশ্যই জানাবেন!!
#
# Status: happy
# Sentence: কাকা গর্বে মনটা ভরে গেল।তোমাকে অসংখ্য ধন্যবাদ।আল্লা তোমার মঙ্গল করুন।
#
# Status: happy
# Sentence: বন্ধু....তোমার তো অনেক ক্ষমতা..... একমত..........!!
#
# Status: happy
# Sentence: স্যার আমার পরিবারের সবাই তার জন্য, দোয়াকরি
#
# Status: angry
# Sentence: এই বাচ্চার মা বাবাকে রিমান্ডে নেওয়ার দরকার
#
# Status: angry
# Sentence: এই নাস্তিক ইমরান সরকার কে জুতা
#
# Status: happy
# Sentence: মা বাবার দোয়া অাছে ইনসাল্লা মায়ের ছেলে মায়ের কুলে যাবে
#
# Status: happy
# Sentence: ভাই ' শুভ নববর্ষের শুভেচ্ছা
#
# Status: sad
# Sentence: আললাহ মেহদি জেন ওর মা বাবাকে তারা তাড়ি খুজে পায়
#
# Status: sad
# Sentence: শিশুটির মা এতক্ন হয়তো পাগল হয়ে গেচে
#
# Status: happy
# Sentence: নিঃসন্দেহে নামাজ মানুষকে অশ্লীলতা ও মন্দ কাজ থেকে বিরত রাখে ----[সূরা আন-কাবুত, আয়াত-৪৫]
#
# Status: disgust
# Sentence: স্টুপিড ...মুখে আটা ময়দা মাখতে মাখতে মাথাটাও আটার বস্তা বানাইয়া ফেলছে.... ফুলফিল ননসেন্স...
#
# Status: sad
# Sentence: আললা যেন ওকে তার মা বাবার কাছে পৌছে দেন
#
# Status: sad
# Sentence: এটা ঠিক নয় ' ভালো মন্দ নিয়েই জিবন
#
# Status: sad
# Sentence: মায়ের সনতান মায়ের কোলে ফিরে যাক আললাহর কাছে এটাই কাবব
#
# Status: happy
# Sentence: মেহেদী নামের ৪ বছর বয়সী এই শিশুটিকে কিছুক্ষণ আগে হাতিরঝিলে পাওয়া গেছে। তার বাবার নাম সম্ভবত হাসান। শিশুটির পরিবার খুজে পেতে সকলের সহযোগীতা কাম্য। যোগাযোগঃ পুলিশের গুলশান জোনের ডিসি মোস্তাক আহমেদ অথবা গুলশান থানা
#
# Status: sad
# Sentence: বাবা মার কেলাস নেসের জন্য শিশুটি তাদের হারিয়ে ফেলেছে। কোথাও গেলে দিশেহারা হবেন না।আল্লাহ্‌ শিশুটিকে তার মায়ের কাছে পৌঁছে দিন।
#
# Status: sad
# Sentence: আল্লাহর রহমত ও fb বন্ধুদের শেয়ারে, ডিএমপি র সহযোগিতায় সে বাবা মাকে খুজে পাবেন। কিন্তুু বাবা মা আগামী বৈশাখী আনন্দে মনে রাখবেন তো ???????
#
# Status: angry
# Sentence: ভাই, কন্ডম ছাড়া কাজের সুচনাটা কিন্তু ৭১ এর রাজাকারদের দিয়েই শুরু হয়েছিল.... মুখে দাড়ী, গায়ে ইসলামী পোষাক পরে আপনি যে ভাষা ব্যাবহার করলেন, তাতে আর যাই হোক -আপনাকে আল্লাহ ভিরু বলা যায় না...। আল্লাহ আপনাকে, আমাকে, আমাদের সকল কে ঈমানের পথে রাখুন...আমিন...
#
# Status: disgust
# Sentence: ওর মা হয়ত বৈশাখী মেলায় গিয়ে তোমার মত কোন কন্ডম এইচ,সরকারের ললসার শিকার হয়েছে কিনা খুজ নিয়ে দেখ।
#
# Status: sad
# Sentence: তারিক বন্ধু বাচ্চাটি কি তুই পাইছিস, তাহলে তোকে ধন্যবাদ, দোয়া করি যেন বাবুটিকে তার বাবা-মা খুব তারাতারি পেয়ে যায়।
#
# Status: sad
# Sentence: মেলাতে গিয়ে সন্তান পর্যন্ত হারিয়ে ফেলছে। হায়রে নোংরামির উৎসব!!
#
# Status: sad
# Sentence: কেয়ামতে সর্ব প্রথম হিসাব হবে নামাজের হিসাব হবে। আল্লাহ আমাদের নামাজকে কবুল করুক - আমিন
#
# Status: sad
# Sentence: ভায়ো তার বাবা মার কাছে ফিরে যাওয়ার পর অবশ্যই যানাবেন আমরা অপেক্ষায় আছি।
#
# Status: disgust
# Sentence: কেমন মা বাবা
#
# Status: happy
# Sentence: পুলিশ ভাইদের ধন্যবাদ মেহেদীকে খুজে বের করার জন্য।
#
# Status: happy
# Sentence: ছেলে টি ওর মা বাবার হাতে তোলেদেন ভাল হবে। ধন্যবাদ
#
# Status: sad
# Sentence: সন্তান জেনো মাকে ফিরে পায়
#
# Status: happy
# Sentence: শেয়ার করলাম।
#
# Status: happy
# Sentence: মহান কাজ ভাই; বেঁচে থাকুন।
#
# Status: sad
# Sentence: যদি কেউ ছেলেকে নিতে চায় ?? কি করতে হবে
#
# Status: happy
# Sentence: খুব সুন্দর কথা বলেছেন কিন্তু কোনো উদ্দেশ্য আছে নাকি আবার
#
# Status: happy
# Sentence: মামু এতদিনে লাইনে আইছে মনে হয়?
#
# Status: sad
# Sentence: বলার জন্য তো অনেকেই ওস্তাদ মানার জন্য ......
#
# Status: angry
# Sentence: পৃথিবী যতদিন আছে ধর্ম টিকে থাকবে সব ধর্মই কারণ মানুষের অদৃশ্য শক্তির প্রতি ব্শ্বিাস আচে কিন্তু কিন্তু ধর্ম নিয়ে যারা রাজনীতি করে তারা টিকে থাকবে না ।
#
# Status: happy
# Sentence: সময়ের সাথে সাথে পৃথিবী পরিবর্তন হচ্ছে সুতরাং মুক্ত চিন্তা ঠেকানো সম্ভব না।এটা আস্তে আস্তে পরিবর্তন হতে বাধ্য।
#
# Status: happy
# Sentence: রাইট ভাই,একদম খাঁটি কথা।
#
# Status: angry
# Sentence: আর নাস্তিকরা যখন বিদ্বেষী উস্কানি দিচ্ছে? :)
#
# Status: happy
# Sentence: ধন্যবাদ মিঃ ইমরান সরকার। সত্য,উপলব্দি করার জন্য।। আমিতোমার কট্টর সমালোচক হওয়া সত্বেও।
#
# Status: happy
# Sentence: নির্ভয়ে সত্যটা বলার জন্য ধন্যবাদ
#
# Status: happy
# Sentence: হা ভাই ঠিক বলেছেন । আমরা মুক্ত চিন্তর সংঙ্গা যান্তে চাই
#
# Status: happy
# Sentence: অভিনন্দন মুক্তচিন্তার সংজ্ঞা দেওয়ার জন্য। এগিয়ে যান- দেশের বিরুদ্ধে ষড়যন্ত্রকারীদের প্রতিহত করার আন্দোলনে, সাথেই থাকবো ইনশাআল্লাহ্
#
# Status: angry
# Sentence: ভূতের মুখে রাম নাম !!!!!!!!!!!!!!!!!! তবে হ্যা ঐ ওদের সাইজ করা জরুরী...................................
#
# Status: fear
# Sentence: সংখ্যাধ্যিকের ঠেলায় ভালো ভালো বয়ান বেরিয়ে আসতে বাধ্য হয়!
#
# Status: disgust
# Sentence: বাহ তাহলে এতদিন পরে হলেও বুঝলেন।
#
# Status: happy
# Sentence: মামু, বাশ খাওয়ার ঠিক পর হইসস, নিজে বাচার জন্য,, গুড,,,,,,
#
# Status: angry
# Sentence: ভুতের মুখে রাম নাম!।
#
# Status: sad
# Sentence: সব মুক্তচিন্তা ইসলামের বিরুদ্ধে হচ্ছে ।
#
# Status: happy
# Sentence: অথচ তুমি তাদের পক্ষেই থাকো।কলম চলবে বলো।হা হা হা।
#
# Status: sad
# Sentence: ছলনা ছাড়া অার কি্ছু নয়
#
# Status: angry
# Sentence: লেখা'তো ভালই লিখছস কিন্তু তোর চেয়ে বড় কাছরা চিন্তা ভাবনার মানুষ সারা বাংলায় একটাও পাবিনা।
#
# Status: happy
# Sentence: এতদিন পরে বুঝতে পারার জন্য, আপনাকে ধন্যবাদ
#
# Status: angry
# Sentence: ভন্ডামি করে আরকি
#
# Status: happy
# Sentence: খুব ভালো বলছেন ইমরান ভাই।
#
# Status: happy
# Sentence: ধন্যবাদ ইমরান ভাই.....
#
# Status: happy
# Sentence: শুভ বুদ্ধির উদয় হয়েছে।
#
# Status: surprise
# Sentence: তাহলে নিলাদ্রি নিলয়কে মুক্তচিন্তার অধিকারি কিভাবে বলেন?
#
# Status: sad
# Sentence: উল্টো রথের যাত্রী ইমরান এইচ সরকার বাঁশি তো আগের মতো বাজেনা
#
# Status: happy
# Sentence: আপনার কথাটা ভাল লাগলো #ইমরান_ভাই :)
#
# Status: sad
# Sentence: এই নিরীহ সংখ্যালঘু গোবেচারা হিন্দুদের জন্য কিছু বলো,,,, !
#
# Status: fear
# Sentence: আপনার আসিফ মহিউদ্দীনকে সামলান সে দেশের জন্য একটা গন্ডগুল বাজাবে।
#
# Status: surprise
# Sentence: তাহলে অভিজিৎ কি করে মুক্তমনা হল? সেত ইসলাম ধর্ম নিয়ে খুব বাজে মন্ত্যব করত।
#
# Status: surprise
# Sentence: আপনার প্রতি আমার বিশ্বাস হচ্ছে না, ঠাকুর ঘরে কে রে আমি তো কলা খাইনি।
#
# Status: sad
# Sentence: যারা কোন গুষ্টির দেশবিরোধি এজেন্ডা বাস্তবায়নে সহযোগীতা করাও ভাল মানুষের কাজ হতে পারেনা
#
# Status: fear
# Sentence: তাই বলে কি আমি জঙ্গিবাদ, ধর্মীয় কুসংস্কার এর বিরুদ্ধে বলতে পারবোনা
#
# Status: fear
# Sentence: স্বীকার করছেন যে, জনগোষ্ঠি বৃহত্‍ হলেও বিশৃংখল হয়?
#
# Status: angry
# Sentence: ছল নাই কুত্তার বাগার না, লক্ষি মার পুটকি উদাম। শালা বাইচুদের মুখে কি কথা
#
# Status: sad
# Sentence: কাওকে কটাক্ষ বিদ্বেষ করা কোন সভ্যতা নয় মানুষ মাত্রই ভুল করেন
#
# Status: angry
# Sentence: এতো দিন পরে বুঝতে পারলেন, কারণ কি, নাস্তিক
#
# Status: surprise
# Sentence: তাদের সাথে গলা মিলিয়ে আন্দোলন করলেন কিভাবে?
#
# Status: surprise
# Sentence: মুক্তচিন্তা মানে কি বুঝলাম না?একটু বুঝাইয়া দিবেন কি?
#
# Status: angry
# Sentence: ভারত হারছে হালা ইসটেটাস দেয় না।।।।।হালা।।।ভারেতর দালাল
#
# Status: sad
# Sentence: যথার্থ, তবে কোন হীন উদ্দেশ্য নেইতো?
#
# Status: happy
# Sentence: আপনার আদর্শ একজন প্রকৃত মানুষের মনুষ্যত্ব এর পরিচায়ক ।
#
# Status: surprise
# Sentence: #তাহলে অভিজিৎ এর পক্ষ নিছেন কেন....???
#
# Status: disgust
# Sentence: শুধু, ইসলাম কে কটাক্ষ করাই মানবতা। তাই না দাদা..!
#
# Status: angry
# Sentence: ইমরান ভাই তর কি যে হবে । আললাহ ভাল যানে
#
# Status: sad
# Sentence: আর একটা ও মেয়ে যেন লাঞ্ছিত না হয়।সে যেই হক।এটা যেন সবার প্রতিবাদ হয়।
#
# Status: disgust
# Sentence: এই কথা গুলো বাংলার মানুষ বা সরকার বুজেনা
#
# Status: happy
# Sentence: আপনার মধ্যে অনেক পরিবর্তন আসছে। ধন্যবাদ।
#
# Status: surprise
# Sentence: কিরে তুই কি দার্শনিক হয়ে গিছিস
#
# Status: angry
# Sentence: আজ থেকে ঐ সকল মুক্তমনাদের নতুন নাম দিলাম (কুত্তামনা).......
#
# Status: angry
# Sentence: তুই নাস্তিক সালা তোর এক দিন পাসি হবে
#
# Status: fear
# Sentence: কিন্তু আপনার অনেক লেখায় এগুলোর বিপরীত দেখা যায়!!!
#
# Status: angry
# Sentence: এতদিন পর তাহলে লাইনে আসলেন।আসলে মাইরের নাম বাবাজি।
#
# Status: angry
# Sentence: মাইরের ভয়ে বোল পাল্টাইছস জানোয়ার।
#
# Status: angry
# Sentence: নাস্তিক্য চেতনা কি হল?
#
# Status: sad
# Sentence: তোমার মরন ঘনিয়ে এসেছে
#
# Status: surprise
# Sentence: মুক্ত চিন্তার চর্চা শুধু তারাই করার অধিকার রাখে যারা অন্যের অধিকার সম্পর্কে সচেতন।
#
# Status: fear
# Sentence: তদ্রুপ তাকে আইন বহির্ভুতভাবে হত্যাকরা কোন ধার্মিক লোকের কাজ হতে পারে না !!
#
# Status: angry
# Sentence: ওটা আপনার লোকেরাই করছে।
#
# Status: fear
# Sentence: ইসলাম ছাড়া মানবতা হয়না।
#
# Status: disgust
# Sentence: ধর্ম বিদ্বেষ নাস্তিকতা নয় বরং আরেক ধরনের উগ্র সাম্প্রদায়িকতা।
#
# Status: happy
# Sentence: সাহসী বক্ত‌ব্যের জন্য আপনা‌কে লা‌খো সালাম
#
# Status: happy
# Sentence: অবশেষে লাইনে আইলেন ভাইয়া
#
# Status: sad
# Sentence: মেয়েটা হিজাব পরেও কেন ধর্ষণের স্বীকার হলো? অতএব, হিজাব করার দরকার নাই! . : আচ্ছা! ফেডারেল রিজার্ভে সাইবার সিকিউরিটি থাকার পরেও ৮০০ কোটি টাকা চুরি হলো। অতএব, সাইবার সিকিউরিটির দরকার নাই। আপনারা কি বলেন? বি.দ্র. এখন পর্যন্ত যেসব হিজাবী বোন ধর্ষনের শিকার হয়েছে তারা কেউ-ই শরয়ী হিজাব পরতোনা। সুতরাং হিজাবের দোষ ধরে শাক দিয়ে মাছ ঢাকার ব্যর্থ চেষ্টা করবেন না।
#
# Status: angry
# Sentence: যার বিরুদ্ধে নিজে বললে তা তো নিজেই করেন
#
# Status: angry
# Sentence: একদম ঠিক কথা এরা মানুুষরুপে অন্য জীব
#
# Status: happy
# Sentence: ঠিক কথা বলেছেন আপনাকে ধন্যবাদ
#
# Status: happy
# Sentence: সহমত""
#
# Status: angry
# Sentence: মাদারচোদ, ভাল সাজচ.
#
# Status: angry
# Sentence: ভাল হোন
#
# Status: happy
# Sentence: ভাই লাষ্ট বেশ কটা স্ট্যাটাস বেটার লেগেছে। অনুধাবন থেকে পরিবর্তনের একটা আভাস।
#
# Status: angry
# Sentence: শতাব্দীর শ্রেষ্ঠ শুওরের বাচ্চা ........
#
# Status: sad
# Sentence: মেসেজ ব্লকটা আর খুললে না ?
#
# Status: happy
# Sentence: সত্যি কথা
#
# Status: fear
# Sentence: সুনির্দিষ্ট কোনো জাতি-গোষ্ঠী-ধর্ম-বর্ণ-লিঙ্গের প্রতি সচেতনভাবে বিদ্বেষ ছড়ানো কোনোভাবেই মুক্তচিন্তা কিংবা মুক্তবুদ্ধির চর্চা হতে পারে না। একইভাবে যারা শুধুমাত্র নিজেদের হীন উদ্দেশ্য সাধনের জন্য সম্পূর্ণ যুক্তিহীনভাবে সমাজের বৃহৎ জনগোষ্ঠীকে অকল্যাণ ও বিশৃঙ্খলার মুখে ঠেলে দেন, তারা কোনোভাবেই মুক্তচিন্তক কিংবা মানবতাবাদী হতে পারেন না। -- Dr.Imran H Sarker
#
# Status: happy
# Sentence: অনেক পরে হলেও বুজলেন। ধন্যবাদ :)
#
# Status: happy
# Sentence: ব্যপক বিনুদন পাইলাম... :v
#
# Status: surprise
# Sentence: কিছু বুজলাম না?
#
# Status: sad
# Sentence: মুক্ত চিন্তা মুক্তভা‌বেই চল‌বে! বহতা নদীর ম‌তো। এখা‌নে বাঁধা দি‌তে গে‌লে বিজ্ঞান থে‌মে যা‌বে। ত‌বে কা‌রো বিশ্বা‌সের উপর আঘাত লাগ‌লে সেটা তা‌দেরই বিশ্বা‌ষের দূর্বলতা !
#
# Status: angry
# Sentence: তোমারে কাইটা কুত্তারে খাওয়ামু, খানকির পুলা,
#
# Status: surprise
# Sentence: ভূতের মুখে রাম নাম ?
#
# Status: happy
# Sentence: তাহলে এতদিনে বুঝলা বাবো
#
# Status: surprise
# Sentence: এতদিন পর এটা বুঝতে পারলেন?
#
# Status: happy
# Sentence: ভাই সত্যিই ডরাইছে!হা হা হা হা হা।কথায় অাছেনা যেখানে বাগের ভয় সেখানেই রাত হয়।ইমরাইন-নার মনে এবার অন্ধকার নামতেছে মনে হয় ভাই
#
# Status: fear
# Sentence: বেসম্ভব ডরাইছেন মনে হয়!
#
# Status: disgust
# Sentence: যখন প্রধানমন্ত্রী শেখ হাসিনা বলছে মুক্তমনার নামে ধর্মীয় অনুভুতিতে আঘাত কারীকে আশ্রং দিবেন না।ঠিক তখনই মুত্রমনারা রূপ পাল্টাতে শুরু করছে।
#
# Status: happy
# Sentence: মামায় পল্টি মারছে।
#
# Status: angry
# Sentence: খানকি মাগির পোলা
#
# Status: happy
# Sentence: হাজি বংশের ছেলে যখন ৫ ওয়াক্ত নামাজ পড়েন সঠিক মযাদা পাবেন ইনশাল্লাহ্
#
# Status: happy
# Sentence: ঠিক বলেছ ইমরান...তোমাকে ধন্যবাদ। জয় বাংলা জয় বঙ্গবন্ধু
#
# Status: happy
# Sentence: ঠেলার নাম বাবাজি।
#
# Status: angry
# Sentence: শাহাবাগের মাগীদের দালাল হচ্ছে ইমরান সরকার "'
#
# Status: sad
# Sentence: শুধু তনু হত্যা নয় প্রত্যেক হত্যার বিচার চাই, প্রত্যেক অন্যায়ের বিচার চাই।
#
# Status: surprise
# Sentence: ভারতে প্রতিদিন ১৮ টা রেপ কেইস এন্ট্রি হয়
#
# Status: surprise
# Sentence: এই কি স্বাধীন দেশ
#
# Status: sad
# Sentence: স্বাধীন দেশের নাগরিক হয়ে ও আজ আমরা পরাধীন।
#
# Status: angry
# Sentence: চুদলাম দাদা পয়সা নাই
#
# Status: sad
# Sentence: আমরা মানুষের মত হয়ে বাচতে চায়,পরাধীন হয়ে নয়

# %%
df = pd.DataFrame(extracted_data)
df
# Out:
#         Status                                           Sentence
# 0          sad  বরাবর, মাননীয় প্রধানমন্ত্রী গণপ্রজাতন্ত্রী বা...
# 1          sad  তদন্ত করে লাভ কী ? কোন দিন কোন তদন্তের পর কিছু...
# 2        angry  দেশকি মধ্যম আয়ের দেশে রুপান্তর হচ্ছে নাকি মগের...
# 3        happy  আমি গর্বিত আমি মুসলিম। আমি সংগ্রামী। আমি যোদ্ধ...
# 4        angry                        রাতের বেলা আবার কিসের সকাল।
# ...        ...                                                ...
# 6284  surprise           ভারতে প্রতিদিন ১৮ টা রেপ কেইস এন্ট্রি হয়
# 6285  surprise                                  এই কি স্বাধীন দেশ
# 6286       sad         স্বাধীন দেশের নাগরিক হয়ে ও আজ আমরা পরাধীন।
# 6287     angry                               চুদলাম দাদা পয়সা নাই
# 6288       sad        আমরা মানুষের মত হয়ে বাচতে চায়,পরাধীন হয়ে নয়
#
# [6289 rows x 2 columns]

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split

# Enable eager execution
tf.config.run_functions_eagerly(True)

# Preprocessing
emotional_statuses = {'sad': 0, 'happy': 1, 'angry': 2, 'surprise': 3}
df['Status'] = df['Status'].map(emotional_statuses)
X = df['Sentence']
y = df['Status']

# Tokenize and convert text to sequences
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X)
sequences = tokenizer.texts_to_sequences(X)

# Padding sequences to have the same length
max_seq_length = max(len(seq) for seq in sequences)
X_padded = pad_sequences(sequences, maxlen=max_seq_length, padding='post')

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_padded, y, test_size=0.2, random_state=42)

X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)  # Ensure X_test is a numpy array
y_test = np.array(y_test)  # Ensure y_test is a numpy array

# Create the LSTM model
embedding_dim = 100
vocab_size = len(tokenizer.word_index) + 1

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_seq_length))
model.add(LSTM(64))
model.add(Dense(4, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
epochs = 10
batch_size = 32
try:
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.1)
except Exception as e:
    print("Error during model training:", e)

# Evaluate the model on the test set
try:
    loss, accuracy = model.evaluate(X_test, y_test)
    print(f'Test loss: {loss}, Test accuracy: {accuracy}')
except Exception as e:
    print("Error during model evaluation:", e)
# Out:
# Epoch 1/10
# Error during model training: Graph execution error:
#
# Detected at node 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits' defined at (most recent call last):
#     File "C:\ProgramData\anaconda3\lib\runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\ProgramData\anaconda3\lib\runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "C:\ProgramData\anaconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "C:\ProgramData\anaconda3\lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#       app.start()
#     File "C:\ProgramData\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 711, in start
#       self.io_loop.start()
#     File "C:\ProgramData\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "C:\ProgramData\anaconda3\lib\asyncio\base_events.py", line 603, in run_forever
#       self._run_once()
#     File "C:\ProgramData\anaconda3\lib\asyncio\base_events.py", line 1906, in _run_once
#       handle._run()
#     File "C:\ProgramData\anaconda3\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\ProgramData\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "C:\ProgramData\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "C:\ProgramData\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "C:\ProgramData\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "C:\ProgramData\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 411, in do_execute
#       res = shell.run_cell(
#     File "C:\ProgramData\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 531, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\ProgramData\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2961, in run_cell
#       result = self._run_cell(
#     File "C:\ProgramData\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3016, in _run_cell
#       result = runner(coro)
#     File "C:\ProgramData\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\ProgramData\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3221, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\ProgramData\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3400, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "C:\ProgramData\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3460, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\Pinash\AppData\Local\Temp\ipykernel_11324\4049373584.py", line 48, in <module>
#       model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.1)
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\engine\training.py", line 1685, in fit
#       tmp_logs = self.train_function(iterator)
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\engine\training.py", line 1284, in train_function
#       return step_function(self, iterator)
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\engine\training.py", line 1268, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\engine\training.py", line 1249, in run_step
#       outputs = model.train_step(data)
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\engine\training.py", line 1051, in train_step
#       loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\engine\training.py", line 1109, in compute_loss
#       return self.compiled_loss(
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\engine\compile_utils.py", line 265, in __call__
#       loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\losses.py", line 142, in __call__
#       losses = call_fn(y_true, y_pred)
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\losses.py", line 268, in call
#       return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\losses.py", line 2078, in sparse_categorical_crossentropy
#       return backend.sparse_categorical_crossentropy(
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\backend.py", line 5660, in sparse_categorical_crossentropy
#       res = tf.nn.sparse_softmax_cross_entropy_with_logits(
# Node: 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits'
# Received a label value of -9223372036854775808 which is outside the valid range of [0, 4).  Label values: -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808
# 	 [[{{node sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits}}]] [Op:__inference_train_function_16747]
# Error during model evaluation: Graph execution error:
#
# Detected at node 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits' defined at (most recent call last):
#     File "C:\ProgramData\anaconda3\lib\runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\ProgramData\anaconda3\lib\runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "C:\ProgramData\anaconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "C:\ProgramData\anaconda3\lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#       app.start()
#     File "C:\ProgramData\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 711, in start
#       self.io_loop.start()
#     File "C:\ProgramData\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "C:\ProgramData\anaconda3\lib\asyncio\base_events.py", line 603, in run_forever
#       self._run_once()
#     File "C:\ProgramData\anaconda3\lib\asyncio\base_events.py", line 1906, in _run_once
#       handle._run()
#     File "C:\ProgramData\anaconda3\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\ProgramData\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "C:\ProgramData\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "C:\ProgramData\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "C:\ProgramData\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 729, in execute_request
#       reply_content = await reply_content
#     File "C:\ProgramData\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 411, in do_execute
#       res = shell.run_cell(
#     File "C:\ProgramData\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 531, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\ProgramData\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2961, in run_cell
#       result = self._run_cell(
#     File "C:\ProgramData\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3016, in _run_cell
#       result = runner(coro)
#     File "C:\ProgramData\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\ProgramData\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3221, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\ProgramData\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3400, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "C:\ProgramData\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3460, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\Pinash\AppData\Local\Temp\ipykernel_11324\4049373584.py", line 54, in <module>
#       loss, accuracy = model.evaluate(X_test, y_test)
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\engine\training.py", line 2072, in evaluate
#       tmp_logs = self.test_function(iterator)
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\engine\training.py", line 1852, in test_function
#       return step_function(self, iterator)
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\engine\training.py", line 1836, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\engine\training.py", line 1824, in run_step
#       outputs = model.test_step(data)
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\engine\training.py", line 1790, in test_step
#       self.compute_loss(x, y, y_pred, sample_weight)
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\engine\training.py", line 1109, in compute_loss
#       return self.compiled_loss(
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\engine\compile_utils.py", line 265, in __call__
#       loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\losses.py", line 142, in __call__
#       losses = call_fn(y_true, y_pred)
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\losses.py", line 268, in call
#       return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\losses.py", line 2078, in sparse_categorical_crossentropy
#       return backend.sparse_categorical_crossentropy(
#     File "C:\ProgramData\anaconda3\lib\site-packages\keras\backend.py", line 5660, in sparse_categorical_crossentropy
#       res = tf.nn.sparse_softmax_cross_entropy_with_logits(
# Node: 'sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits'
# Received a label value of -9223372036854775808 which is outside the valid range of [0, 4).  Label values: -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808 -9223372036854775808
# 	 [[{{node sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/SparseSoftmaxCrossEntropyWithLogits}}]] [Op:__inference_test_function_17340]
